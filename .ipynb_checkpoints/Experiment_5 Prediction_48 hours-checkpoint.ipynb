# %%
#Installing all the necessary packages in order to undergo the prediction
import numpy as np
from math import sqrt
import pandas as pd
from pandas import Series , concat
from pandas import DataFrame , datetime
from pandas import read_csv
import pandas as pd
from keras.models import Sequential
# Out:
# Using TensorFlow backend.

# %%
#Loading the data set
dataset = pd.read_csv('C:/Users/gurun/Desktop/ProjectCPS/EXP3/DPPdataset.csv',index_col="DATETIME")
dataset.head()
# Out:
#                air temp degree  Air density  wind speed at 100m (m/s)  \
# DATETIME
# 1/1/2007 0:00            2.430        1.223                    11.673
# 1/1/2007 0:05            2.387        1.224                    11.395
# 1/1/2007 0:10            2.336        1.224                    11.468
# 1/1/2007 0:15            2.278        1.224                    11.636
# 1/1/2007 0:20            2.192        1.225                    11.727
#
#                wind direction at 100m (deg)  Power (KW)
# DATETIME
# 1/1/2007 0:00                       244.189       15701
# 1/1/2007 0:05                       244.755       15498
# 1/1/2007 0:10                       245.644       15568
# 1/1/2007 0:15                       246.863       15691
# 1/1/2007 0:20                       247.287       15719

# %%
# Framing the the sequence as a supervised learning problem
def timeseries_to_supervised(data, lag=1):
    df_set = DataFrame(data)
    columns = [df_set.shift(i) for i in range(1, lag+1)]
    columns.append(df_set)
    df_set = concat(columns, axis=1)
    df_set.fillna(0, inplace=True)
    return df_set

# %%
# creating a differenced series
def difference(Data_Set, interval=1):
    diff = list()
    for i in range(interval, len(Data_Set)):
        value = Data_Set[i] - Data_Set[i - interval]
        diff.append(value)
    return Series(diff)
# inverting the differenced value
def inverse_difference(history, Y_pred, interval=1):
    return Y_pred + history[-interval]

# %%
# Dropping all the features which we will not be using
del dataset['air temp degree']
del dataset['Air density']
del dataset['wind speed at 100m (m/s)']
del dataset['wind direction at 100m (deg)']
for i in range(0,15):
  dataset = dataset[:-1]
dataset.tail()
# Out:
#                   Power (KW)
# DATETIME
# 12/31/2007 22:20       16000
# 12/31/2007 22:25       16000
# 12/31/2007 22:30       16000
# 12/31/2007 22:35       16000
# 12/31/2007 22:40       16000

# %%
# Performing scaling on the train data to [-1, 1]
from sklearn.preprocessing import MinMaxScaler
def scale(Xtrain, Xtest):
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler = scaler.fit(Xtrain)
    Xtrain = Xtrain.reshape(Xtrain.shape[0], Xtrain.shape[1])
    Xtrain_scaled = scaler.transform(Xtrain)
    
    
# Performing scaling on the test data to [-1, 1]
    Xtest = Xtest.reshape(Xtest.shape[0], Xtest.shape[1])
    Xtest_scaled = scaler.transform(Xtest)
    return scaler, Xtrain_scaled, Xtest_scaled

# %%
# Performing inverse scaling for a forecasted value
def invert_scale(scaler, X, value):
    np_rowval = [x for x in X] + [value]
    array = np.array(np_rowval)
    array = array.reshape(1, len(array))
    inverted = scaler.inverse_transform(array)
    return inverted[0, -1]

# %%
# Hardcoding all variables
Lag_duration =24
Predict_Value_Size= 576
Epoch_Size = 6
Batch_Size = 1
Neurons_Size = 10

# %%
# fitting the LSTM model into a Training Data set
from keras.layers import Dense, LSTM
from keras.models import Sequential
def fit_lstm(Xtrain, batch_size, nb_epoch, neurons):
    X, y = Xtrain[:, 0:-1], Xtrain[:, -1]
    X = X.reshape(X.shape[0], 1, X.shape[1])
    
    model = Sequential()
    model.add(LSTM(neurons, batch_input_shape=(Batch_Size, X.shape[1], X.shape[2]), stateful=True))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    for i in range(nb_epoch):
        model.fit(X, y, epochs=1, batch_size=batch_size, verbose=1, shuffle=False)
        model.reset_states()
    return model

# %%
# Variables Required for performing forwad walk validation on the test data set
Prediction = list()
Expectation = list()
Pred_plot = list()
Expectation_plot = list()
Test_Prediction = list()

# %%
# making an one-step forecast
def forecast_lstm(model, batch_size, X):
    X = X.reshape(1, 1, len(X))
    Y_pred = model.predict(X, batch_size=1)
    return Y_pred[0,0]

# %%
# transforming the data into a stationary data set
Raw_val = dataset.values
Different_val = difference(Raw_val, 1)
# transforming the data into a  supervised learning
supervised = timeseries_to_supervised(Different_val, Lag_duration)
supervised_values = supervised.values

# %%
# splitting the dataset into train-sets and test-sets
Xtrain, Xtest = supervised_values[0:-Predict_Value_Size], supervised_values[-Predict_Value_Size:]
# perform scaling on the data
scaler, Xtrain_scaled, Xtest_scaled = scale(Xtrain, Xtest)
# Out:
# C:\Users\gurun\AppData\Local\conda\conda\envs\tensorflow-sessions\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype object was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
# fitting the LSTM model 
lstm_model = fit_lstm(Xtrain_scaled, Batch_Size, Epoch_Size, Neurons_Size)
# Out:
# Epoch 1/1
# 104528/104528 [==============================] - 98s 941us/step - loss: 0.0011
# Epoch 1/1
# 104528/104528 [==============================] - 108s 1ms/step - loss: 0.0011
# Epoch 1/1
# 104528/104528 [==============================] - 107s 1ms/step - loss: 0.0010
# Epoch 1/1
# 104528/104528 [==============================] - 107s 1ms/step - loss: 0.0010
# Epoch 1/1
# 104528/104528 [==============================] - 107s 1ms/step - loss: 0.0010
# Epoch 1/1
# 104528/104528 [==============================] - 112s 1ms/step - loss: 0.0010

# %%
for i in range(len(Xtest_scaled)):
    # making one-step forecast
    X, y = Xtest_scaled[i, 0:-1], Xtest_scaled[i, -1]
    Y_pred = forecast_lstm(lstm_model, 1, X)
    # Replacing the values of test scaled data with the newly predicted value.
    Test_Prediction = [Y_pred] + Test_Prediction 
    if len(Test_Prediction) > Lag_duration+1:
        Test_Prediction = Test_Prediction[:-1]
    if i+1<len(Xtest_scaled):
        if i+1 > Lag_duration+1:
            Xtest_scaled[i+1] = Test_Prediction
        else:
            Xtest_scaled[i+1] = np.concatenate((Test_Prediction, Xtest_scaled[i+1, i+1:]),axis=0)

    #Performing the invert scaling and invert differencing and store the forecasted values into an array
    Y_pred = invert_scale(scaler, X, Y_pred)
    Y_pred = inverse_difference(Raw_val, Y_pred, len(Xtest_scaled)+1-i)
    Expected_Val = Raw_val[len(Xtrain) + i + 1]
    Pred_plot.append(Y_pred)
    Expectation_plot.append(Expected_Val)
    if Expected_Val != 0:
        Prediction.append(Y_pred)
        Expectation.append(Expected_Val)
    print('Every 5th Minute Entry=%d, Predicted_Value=%f, Expected_Value=%f' % (i+1, Y_pred, Expected_Val))

Expectation = np.array(Expectation)
Prediction = np.array(Prediction)
# Out:
# Every 5th Minute Entry=1, Predicted_Value=13287.930229, Expected_Value=13182.000000
# Every 5th Minute Entry=2, Predicted_Value=13356.554596, Expected_Value=13152.000000
# Every 5th Minute Entry=3, Predicted_Value=13313.785926, Expected_Value=13065.000000
# Every 5th Minute Entry=4, Predicted_Value=13180.386312, Expected_Value=12966.000000
# Every 5th Minute Entry=5, Predicted_Value=13040.568463, Expected_Value=12872.000000
# Every 5th Minute Entry=6, Predicted_Value=12916.698375, Expected_Value=12852.000000
# Every 5th Minute Entry=7, Predicted_Value=12873.826034, Expected_Value=12881.000000
# Every 5th Minute Entry=8, Predicted_Value=12878.192744, Expected_Value=12917.000000
# Every 5th Minute Entry=9, Predicted_Value=12891.674204, Expected_Value=12947.000000
# Every 5th Minute Entry=10, Predicted_Value=12902.330826, Expected_Value=12984.000000
# Every 5th Minute Entry=11, Predicted_Value=12925.757157, Expected_Value=13021.000000
# Every 5th Minute Entry=12, Predicted_Value=12952.739507, Expected_Value=13045.000000
# Every 5th Minute Entry=13, Predicted_Value=12975.322533, Expected_Value=13077.000000
# Every 5th Minute Entry=14, Predicted_Value=13013.127357, Expected_Value=13053.000000
# Every 5th Minute Entry=15, Predicted_Value=13001.459848, Expected_Value=12991.000000
# Every 5th Minute Entry=16, Predicted_Value=12950.627023, Expected_Value=12910.000000
# Every 5th Minute Entry=17, Predicted_Value=12878.023192, Expected_Value=12841.000000
# Every 5th Minute Entry=18, Predicted_Value=12805.779567, Expected_Value=12790.000000
# Every 5th Minute Entry=19, Predicted_Value=12745.375990, Expected_Value=12758.000000
# Every 5th Minute Entry=20, Predicted_Value=12700.666397, Expected_Value=12745.000000
# Every 5th Minute Entry=21, Predicted_Value=12671.809028, Expected_Value=12727.000000
# Every 5th Minute Entry=22, Predicted_Value=12636.487202, Expected_Value=12715.000000
# Every 5th Minute Entry=23, Predicted_Value=12611.524294, Expected_Value=12746.000000
# Every 5th Minute Entry=24, Predicted_Value=12641.621017, Expected_Value=12821.000000
# Every 5th Minute Entry=25, Predicted_Value=12721.695711, Expected_Value=12957.000000
# Every 5th Minute Entry=26, Predicted_Value=12868.881990, Expected_Value=13100.000000
# Every 5th Minute Entry=27, Predicted_Value=13033.088018, Expected_Value=13150.000000
# Every 5th Minute Entry=28, Predicted_Value=13113.698947, Expected_Value=13107.000000
# Every 5th Minute Entry=29, Predicted_Value=13104.380687, Expected_Value=13015.000000
# Every 5th Minute Entry=30, Predicted_Value=13043.215338, Expected_Value=12935.000000
# Every 5th Minute Entry=31, Predicted_Value=12987.794409, Expected_Value=12943.000000
# Every 5th Minute Entry=32, Predicted_Value=13013.723904, Expected_Value=13056.000000
# Every 5th Minute Entry=33, Predicted_Value=13138.179731, Expected_Value=13217.000000
# Every 5th Minute Entry=34, Predicted_Value=13304.772097, Expected_Value=13334.000000
# Every 5th Minute Entry=35, Predicted_Value=13422.485222, Expected_Value=13371.000000
# Every 5th Minute Entry=36, Predicted_Value=13457.166075, Expected_Value=13340.000000
# Every 5th Minute Entry=37, Predicted_Value=13421.968267, Expected_Value=13315.000000
# Every 5th Minute Entry=38, Predicted_Value=13392.168531, Expected_Value=13303.000000
# Every 5th Minute Entry=39, Predicted_Value=13375.551770, Expected_Value=13302.000000
# Every 5th Minute Entry=40, Predicted_Value=13371.253595, Expected_Value=13344.000000
# Every 5th Minute Entry=41, Predicted_Value=13411.329217, Expected_Value=13349.000000
# Every 5th Minute Entry=42, Predicted_Value=13415.625699, Expected_Value=13373.000000
# Every 5th Minute Entry=43, Predicted_Value=13438.936316, Expected_Value=13384.000000
# Every 5th Minute Entry=44, Predicted_Value=13447.567919, Expected_Value=13359.000000
# Every 5th Minute Entry=45, Predicted_Value=13417.380592, Expected_Value=13321.000000
# Every 5th Minute Entry=46, Predicted_Value=13370.474369, Expected_Value=13258.000000
# Every 5th Minute Entry=47, Predicted_Value=13294.177868, Expected_Value=13189.000000
# Every 5th Minute Entry=48, Predicted_Value=13206.920299, Expected_Value=13133.000000
# Every 5th Minute Entry=49, Predicted_Value=13128.576783, Expected_Value=13084.000000
# Every 5th Minute Entry=50, Predicted_Value=13054.803474, Expected_Value=13096.000000
# Every 5th Minute Entry=51, Predicted_Value=13041.151513, Expected_Value=13109.000000
# Every 5th Minute Entry=52, Predicted_Value=13029.110534, Expected_Value=13128.000000
# Every 5th Minute Entry=53, Predicted_Value=13025.522979, Expected_Value=13148.000000
# Every 5th Minute Entry=54, Predicted_Value=13027.247853, Expected_Value=13185.000000
# Every 5th Minute Entry=55, Predicted_Value=13051.646587, Expected_Value=13210.000000
# Every 5th Minute Entry=56, Predicted_Value=13070.223824, Expected_Value=13253.000000
# Every 5th Minute Entry=57, Predicted_Value=13112.752199, Expected_Value=13264.000000
# Every 5th Minute Entry=58, Predicted_Value=13128.480600, Expected_Value=13226.000000
# Every 5th Minute Entry=59, Predicted_Value=13099.366946, Expected_Value=13193.000000
# Every 5th Minute Entry=60, Predicted_Value=13078.206389, Expected_Value=13141.000000
# Every 5th Minute Entry=61, Predicted_Value=13039.944591, Expected_Value=13102.000000
# Every 5th Minute Entry=62, Predicted_Value=13015.775007, Expected_Value=13069.000000
# Every 5th Minute Entry=63, Predicted_Value=12998.243459, Expected_Value=13031.000000
# Every 5th Minute Entry=64, Predicted_Value=12976.146213, Expected_Value=12987.000000
# Every 5th Minute Entry=65, Predicted_Value=12948.536383, Expected_Value=12949.000000
# Every 5th Minute Entry=66, Predicted_Value=12927.612624, Expected_Value=12917.000000
# Every 5th Minute Entry=67, Predicted_Value=12913.615773, Expected_Value=12884.000000
# Every 5th Minute Entry=68, Predicted_Value=12899.700645, Expected_Value=12827.000000
# Every 5th Minute Entry=69, Predicted_Value=12862.728106, Expected_Value=12690.000000
# Every 5th Minute Entry=70, Predicted_Value=12746.228518, Expected_Value=12478.000000
# Every 5th Minute Entry=71, Predicted_Value=12554.459382, Expected_Value=12149.000000
# Every 5th Minute Entry=72, Predicted_Value=12244.537298, Expected_Value=11811.000000
# Every 5th Minute Entry=73, Predicted_Value=11923.474072, Expected_Value=11420.000000
# Every 5th Minute Entry=74, Predicted_Value=11546.275106, Expected_Value=11030.000000
# Every 5th Minute Entry=75, Predicted_Value=11166.112874, Expected_Value=10694.000000
# Every 5th Minute Entry=76, Predicted_Value=10835.452035, Expected_Value=10420.000000
# Every 5th Minute Entry=77, Predicted_Value=10562.045791, Expected_Value=10210.000000
# Every 5th Minute Entry=78, Predicted_Value=10347.897674, Expected_Value=10062.000000
# Every 5th Minute Entry=79, Predicted_Value=10191.236705, Expected_Value=10012.000000
# Every 5th Minute Entry=80, Predicted_Value=10128.499175, Expected_Value=10023.000000
# Every 5th Minute Entry=81, Predicted_Value=10123.269784, Expected_Value=10059.000000
# Every 5th Minute Entry=82, Predicted_Value=10140.202690, Expected_Value=10104.000000
# Every 5th Minute Entry=83, Predicted_Value=10163.942444, Expected_Value=10192.000000
# Every 5th Minute Entry=84, Predicted_Value=10229.081365, Expected_Value=10361.000000
# Every 5th Minute Entry=85, Predicted_Value=10374.124098, Expected_Value=10618.000000
# Every 5th Minute Entry=86, Predicted_Value=10606.486943, Expected_Value=10831.000000
# Every 5th Minute Entry=87, Predicted_Value=10794.520721, Expected_Value=11043.000000
# Every 5th Minute Entry=88, Predicted_Value=10981.565211, Expected_Value=11211.000000
# Every 5th Minute Entry=89, Predicted_Value=11125.003808, Expected_Value=11256.000000
# Every 5th Minute Entry=90, Predicted_Value=11146.308799, Expected_Value=11213.000000
# Every 5th Minute Entry=91, Predicted_Value=11081.073058, Expected_Value=11081.000000
# Every 5th Minute Entry=92, Predicted_Value=10929.017107, Expected_Value=10923.000000
# Every 5th Minute Entry=93, Predicted_Value=10753.979626, Expected_Value=10817.000000
# Every 5th Minute Entry=94, Predicted_Value=10634.870294, Expected_Value=10764.000000
# Every 5th Minute Entry=95, Predicted_Value=10573.587090, Expected_Value=10719.000000
# Every 5th Minute Entry=96, Predicted_Value=10525.909062, Expected_Value=10694.000000
# Every 5th Minute Entry=97, Predicted_Value=10504.395843, Expected_Value=10669.000000
# Every 5th Minute Entry=98, Predicted_Value=10489.305167, Expected_Value=10652.000000
# Every 5th Minute Entry=99, Predicted_Value=10488.531245, Expected_Value=10583.000000
# Every 5th Minute Entry=100, Predicted_Value=10441.577497, Expected_Value=10565.000000
# Every 5th Minute Entry=101, Predicted_Value=10450.578521, Expected_Value=10521.000000
# Every 5th Minute Entry=102, Predicted_Value=10437.369664, Expected_Value=10566.000000
# Every 5th Minute Entry=103, Predicted_Value=10515.592036, Expected_Value=10636.000000
# Every 5th Minute Entry=104, Predicted_Value=10619.817178, Expected_Value=10653.000000
# Every 5th Minute Entry=105, Predicted_Value=10670.677916, Expected_Value=10652.000000
# Every 5th Minute Entry=106, Predicted_Value=10701.981772, Expected_Value=10661.000000
# Every 5th Minute Entry=107, Predicted_Value=10740.789801, Expected_Value=10688.000000
# Every 5th Minute Entry=108, Predicted_Value=10794.442324, Expected_Value=10689.000000
# Every 5th Minute Entry=109, Predicted_Value=10818.536510, Expected_Value=10725.000000
# Every 5th Minute Entry=110, Predicted_Value=10873.866526, Expected_Value=10770.000000
# Every 5th Minute Entry=111, Predicted_Value=10934.347898, Expected_Value=10931.000000
# Every 5th Minute Entry=112, Predicted_Value=11106.943964, Expected_Value=11109.000000
# Every 5th Minute Entry=113, Predicted_Value=11292.609230, Expected_Value=11112.000000
# Every 5th Minute Entry=114, Predicted_Value=11299.258446, Expected_Value=11193.000000
# Every 5th Minute Entry=115, Predicted_Value=11379.760540, Expected_Value=11237.000000
# Every 5th Minute Entry=116, Predicted_Value=11418.953185, Expected_Value=10850.000000
# Every 5th Minute Entry=117, Predicted_Value=11022.669419, Expected_Value=10699.000000
# Every 5th Minute Entry=118, Predicted_Value=10857.772316, Expected_Value=10663.000000
# Every 5th Minute Entry=119, Predicted_Value=10803.194184, Expected_Value=9667.000000
# Every 5th Minute Entry=120, Predicted_Value=9783.975439, Expected_Value=9176.000000
# Every 5th Minute Entry=121, Predicted_Value=9265.298945, Expected_Value=8880.000000
# Every 5th Minute Entry=122, Predicted_Value=8937.518282, Expected_Value=8161.000000
# Every 5th Minute Entry=123, Predicted_Value=8183.180056, Expected_Value=7292.000000
# Every 5th Minute Entry=124, Predicted_Value=7276.039353, Expected_Value=6727.000000
# Every 5th Minute Entry=125, Predicted_Value=6671.065262, Expected_Value=6349.000000
# Every 5th Minute Entry=126, Predicted_Value=6252.434363, Expected_Value=5906.000000
# Every 5th Minute Entry=127, Predicted_Value=5769.501461, Expected_Value=5391.000000
# Every 5th Minute Entry=128, Predicted_Value=5216.746914, Expected_Value=5153.000000
# Every 5th Minute Entry=129, Predicted_Value=4944.696575, Expected_Value=4995.000000
# Every 5th Minute Entry=130, Predicted_Value=4757.821969, Expected_Value=4852.000000
# Every 5th Minute Entry=131, Predicted_Value=4592.435166, Expected_Value=4473.000000
# Every 5th Minute Entry=132, Predicted_Value=4198.596910, Expected_Value=4122.000000
# Every 5th Minute Entry=133, Predicted_Value=3841.050692, Expected_Value=4021.000000
# Every 5th Minute Entry=134, Predicted_Value=3742.191061, Expected_Value=4311.000000
# Every 5th Minute Entry=135, Predicted_Value=4043.059536, Expected_Value=4252.000000
# Every 5th Minute Entry=136, Predicted_Value=4003.357971, Expected_Value=4086.000000
# Every 5th Minute Entry=137, Predicted_Value=3864.467874, Expected_Value=3765.000000
# Every 5th Minute Entry=138, Predicted_Value=3577.470841, Expected_Value=3461.000000
# Every 5th Minute Entry=139, Predicted_Value=3313.169310, Expected_Value=3216.000000
# Every 5th Minute Entry=140, Predicted_Value=3112.099820, Expected_Value=2896.000000
# Every 5th Minute Entry=141, Predicted_Value=2838.657674, Expected_Value=2355.000000
# Every 5th Minute Entry=142, Predicted_Value=2345.200740, Expected_Value=1976.000000
# Every 5th Minute Entry=143, Predicted_Value=2013.003626, Expected_Value=1680.000000
# Every 5th Minute Entry=144, Predicted_Value=1761.496421, Expected_Value=1503.000000
# Every 5th Minute Entry=145, Predicted_Value=1625.403714, Expected_Value=1403.000000
# Every 5th Minute Entry=146, Predicted_Value=1561.787444, Expected_Value=1187.000000
# Every 5th Minute Entry=147, Predicted_Value=1377.034422, Expected_Value=1064.000000
# Every 5th Minute Entry=148, Predicted_Value=1279.801335, Expected_Value=971.000000
# Every 5th Minute Entry=149, Predicted_Value=1206.926191, Expected_Value=883.000000
# Every 5th Minute Entry=150, Predicted_Value=1133.339422, Expected_Value=816.000000
# Every 5th Minute Entry=151, Predicted_Value=1074.993764, Expected_Value=776.000000
# Every 5th Minute Entry=152, Predicted_Value=1037.825725, Expected_Value=769.000000
# Every 5th Minute Entry=153, Predicted_Value=1027.750719, Expected_Value=740.000000
# Every 5th Minute Entry=154, Predicted_Value=989.675215, Expected_Value=720.000000
# Every 5th Minute Entry=155, Predicted_Value=954.518382, Expected_Value=728.000000
# Every 5th Minute Entry=156, Predicted_Value=941.239695, Expected_Value=795.000000
# Every 5th Minute Entry=157, Predicted_Value=980.869410, Expected_Value=929.000000
# Every 5th Minute Entry=158, Predicted_Value=1081.534625, Expected_Value=1081.000000
# Every 5th Minute Entry=159, Predicted_Value=1194.477946, Expected_Value=1169.000000
# Every 5th Minute Entry=160, Predicted_Value=1238.083430, Expected_Value=1280.000000
# Every 5th Minute Entry=161, Predicted_Value=1299.915018, Expected_Value=1409.000000
# Every 5th Minute Entry=162, Predicted_Value=1375.773181, Expected_Value=1527.000000
# Every 5th Minute Entry=163, Predicted_Value=1437.766476, Expected_Value=1607.000000
# Every 5th Minute Entry=164, Predicted_Value=1460.371950, Expected_Value=1661.000000
# Every 5th Minute Entry=165, Predicted_Value=1457.458655, Expected_Value=1740.000000
# Every 5th Minute Entry=166, Predicted_Value=1482.237634, Expected_Value=1855.000000
# Every 5th Minute Entry=167, Predicted_Value=1548.143870, Expected_Value=1923.000000
# Every 5th Minute Entry=168, Predicted_Value=1574.631337, Expected_Value=1942.000000
# Every 5th Minute Entry=169, Predicted_Value=1561.927420, Expected_Value=1930.000000
# Every 5th Minute Entry=170, Predicted_Value=1529.817030, Expected_Value=1910.000000
# Every 5th Minute Entry=171, Predicted_Value=1502.500376, Expected_Value=1887.000000
# Every 5th Minute Entry=172, Predicted_Value=1485.543167, Expected_Value=1894.000000
# Every 5th Minute Entry=173, Predicted_Value=1512.139418, Expected_Value=1848.000000
# Every 5th Minute Entry=174, Predicted_Value=1498.826228, Expected_Value=1756.000000
# Every 5th Minute Entry=175, Predicted_Value=1451.105460, Expected_Value=1698.000000
# Every 5th Minute Entry=176, Predicted_Value=1446.879370, Expected_Value=1752.000000
# Every 5th Minute Entry=177, Predicted_Value=1561.789168, Expected_Value=1855.000000
# Every 5th Minute Entry=178, Predicted_Value=1730.311862, Expected_Value=1954.000000
# Every 5th Minute Entry=179, Predicted_Value=1896.833581, Expected_Value=2030.000000
# Every 5th Minute Entry=180, Predicted_Value=2039.784513, Expected_Value=2106.000000
# Every 5th Minute Entry=181, Predicted_Value=2179.829278, Expected_Value=2133.000000
# Every 5th Minute Entry=182, Predicted_Value=2266.073866, Expected_Value=2094.000000
# Every 5th Minute Entry=183, Predicted_Value=2280.207531, Expected_Value=2052.000000
# Every 5th Minute Entry=184, Predicted_Value=2283.607026, Expected_Value=2040.000000
# Every 5th Minute Entry=185, Predicted_Value=2308.816515, Expected_Value=2006.000000
# Every 5th Minute Entry=186, Predicted_Value=2304.325237, Expected_Value=1987.000000
# Every 5th Minute Entry=187, Predicted_Value=2307.738983, Expected_Value=1975.000000
# Every 5th Minute Entry=188, Predicted_Value=2311.370919, Expected_Value=1872.000000
# Every 5th Minute Entry=189, Predicted_Value=2217.264553, Expected_Value=1753.000000
# Every 5th Minute Entry=190, Predicted_Value=2100.259382, Expected_Value=1684.000000
# Every 5th Minute Entry=191, Predicted_Value=2026.066147, Expected_Value=1734.000000
# Every 5th Minute Entry=192, Predicted_Value=2063.329942, Expected_Value=1779.000000
# Every 5th Minute Entry=193, Predicted_Value=2087.707952, Expected_Value=1756.000000
# Every 5th Minute Entry=194, Predicted_Value=2035.968010, Expected_Value=1737.000000
# Every 5th Minute Entry=195, Predicted_Value=1980.018240, Expected_Value=1733.000000
# Every 5th Minute Entry=196, Predicted_Value=1930.903532, Expected_Value=1786.000000
# Every 5th Minute Entry=197, Predicted_Value=1930.811387, Expected_Value=1931.000000
# Every 5th Minute Entry=198, Predicted_Value=2015.094060, Expected_Value=2080.000000
# Every 5th Minute Entry=199, Predicted_Value=2096.345417, Expected_Value=2219.000000
# Every 5th Minute Entry=200, Predicted_Value=2161.486073, Expected_Value=2461.000000
# Every 5th Minute Entry=201, Predicted_Value=2324.934548, Expected_Value=2757.000000
# Every 5th Minute Entry=202, Predicted_Value=2539.805922, Expected_Value=3069.000000
# Every 5th Minute Entry=203, Predicted_Value=2771.035626, Expected_Value=3354.000000
# Every 5th Minute Entry=204, Predicted_Value=2979.327978, Expected_Value=3591.000000
# Every 5th Minute Entry=205, Predicted_Value=3147.782619, Expected_Value=3742.000000
# Every 5th Minute Entry=206, Predicted_Value=3242.364140, Expected_Value=3892.000000
# Every 5th Minute Entry=207, Predicted_Value=3351.353931, Expected_Value=4166.000000
# Every 5th Minute Entry=208, Predicted_Value=3602.060649, Expected_Value=4612.000000
# Every 5th Minute Entry=209, Predicted_Value=4043.962223, Expected_Value=5123.000000
# Every 5th Minute Entry=210, Predicted_Value=4571.274212, Expected_Value=5506.000000
# Every 5th Minute Entry=211, Predicted_Value=4989.955750, Expected_Value=5711.000000
# Every 5th Minute Entry=212, Predicted_Value=5247.585546, Expected_Value=5917.000000
# Every 5th Minute Entry=213, Predicted_Value=5520.420421, Expected_Value=6066.000000
# Every 5th Minute Entry=214, Predicted_Value=5747.555423, Expected_Value=6066.000000
# Every 5th Minute Entry=215, Predicted_Value=5833.819476, Expected_Value=5974.000000
# Every 5th Minute Entry=216, Predicted_Value=5832.704596, Expected_Value=5811.000000
# Every 5th Minute Entry=217, Predicted_Value=5761.409844, Expected_Value=5619.000000
# Every 5th Minute Entry=218, Predicted_Value=5658.123014, Expected_Value=5562.000000
# Every 5th Minute Entry=219, Predicted_Value=5683.493259, Expected_Value=5682.000000
# Every 5th Minute Entry=220, Predicted_Value=5877.119716, Expected_Value=5795.000000
# Every 5th Minute Entry=221, Predicted_Value=6053.853966, Expected_Value=5831.000000
# Every 5th Minute Entry=222, Predicted_Value=6143.712572, Expected_Value=5830.000000
# Every 5th Minute Entry=223, Predicted_Value=6186.464139, Expected_Value=5873.000000
# Every 5th Minute Entry=224, Predicted_Value=6262.875558, Expected_Value=5894.000000
# Every 5th Minute Entry=225, Predicted_Value=6308.215393, Expected_Value=5893.000000
# Every 5th Minute Entry=226, Predicted_Value=6323.729405, Expected_Value=6049.000000
# Every 5th Minute Entry=227, Predicted_Value=6488.726342, Expected_Value=6240.000000
# Every 5th Minute Entry=228, Predicted_Value=6680.767981, Expected_Value=6551.000000
# Every 5th Minute Entry=229, Predicted_Value=6984.088139, Expected_Value=6809.000000
# Every 5th Minute Entry=230, Predicted_Value=7224.849850, Expected_Value=6907.000000
# Every 5th Minute Entry=231, Predicted_Value=7295.419383, Expected_Value=6870.000000
# Every 5th Minute Entry=232, Predicted_Value=7220.467340, Expected_Value=6852.000000
# Every 5th Minute Entry=233, Predicted_Value=7153.997919, Expected_Value=6869.000000
# Every 5th Minute Entry=234, Predicted_Value=7112.165989, Expected_Value=6994.000000
# Every 5th Minute Entry=235, Predicted_Value=7168.210180, Expected_Value=7136.000000
# Every 5th Minute Entry=236, Predicted_Value=7231.465963, Expected_Value=7341.000000
# Every 5th Minute Entry=237, Predicted_Value=7348.381222, Expected_Value=7510.000000
# Every 5th Minute Entry=238, Predicted_Value=7420.672063, Expected_Value=7572.000000
# Every 5th Minute Entry=239, Predicted_Value=7378.730615, Expected_Value=7687.000000
# Every 5th Minute Entry=240, Predicted_Value=7385.245066, Expected_Value=7910.000000
# Every 5th Minute Entry=241, Predicted_Value=7499.670514, Expected_Value=8186.000000
# Every 5th Minute Entry=242, Predicted_Value=7673.062890, Expected_Value=8552.000000
# Every 5th Minute Entry=243, Predicted_Value=7949.195226, Expected_Value=8792.000000
# Every 5th Minute Entry=244, Predicted_Value=8118.180431, Expected_Value=8970.000000
# Every 5th Minute Entry=245, Predicted_Value=8248.246240, Expected_Value=9157.000000
# Every 5th Minute Entry=246, Predicted_Value=8413.078852, Expected_Value=9040.000000
# Every 5th Minute Entry=247, Predicted_Value=8301.837297, Expected_Value=8780.000000
# Every 5th Minute Entry=248, Predicted_Value=8074.102173, Expected_Value=8666.000000
# Every 5th Minute Entry=249, Predicted_Value=8015.481443, Expected_Value=8578.000000
# Every 5th Minute Entry=250, Predicted_Value=8002.486888, Expected_Value=8273.000000
# Every 5th Minute Entry=251, Predicted_Value=7788.793281, Expected_Value=8725.000000
# Every 5th Minute Entry=252, Predicted_Value=8344.983848, Expected_Value=9205.000000
# Every 5th Minute Entry=253, Predicted_Value=8938.157272, Expected_Value=9418.000000
# Every 5th Minute Entry=254, Predicted_Value=9268.620930, Expected_Value=9170.000000
# Every 5th Minute Entry=255, Predicted_Value=9136.981001, Expected_Value=9233.000000
# Every 5th Minute Entry=256, Predicted_Value=9309.748585, Expected_Value=9642.000000
# Every 5th Minute Entry=257, Predicted_Value=9817.332651, Expected_Value=10031.000000
# Every 5th Minute Entry=258, Predicted_Value=10291.085923, Expected_Value=10394.000000
# Every 5th Minute Entry=259, Predicted_Value=10724.735984, Expected_Value=10783.000000
# Every 5th Minute Entry=260, Predicted_Value=11171.823152, Expected_Value=11628.000000
# Every 5th Minute Entry=261, Predicted_Value=12064.489010, Expected_Value=12316.000000
# Every 5th Minute Entry=262, Predicted_Value=12789.762656, Expected_Value=12567.000000
# Every 5th Minute Entry=263, Predicted_Value=13067.568835, Expected_Value=12455.000000
# Every 5th Minute Entry=264, Predicted_Value=12973.585180, Expected_Value=12215.000000
# Every 5th Minute Entry=265, Predicted_Value=12743.482026, Expected_Value=11965.000000
# Every 5th Minute Entry=266, Predicted_Value=12494.324237, Expected_Value=11768.000000
# Every 5th Minute Entry=267, Predicted_Value=12287.581877, Expected_Value=11510.000000
# Every 5th Minute Entry=268, Predicted_Value=12007.871869, Expected_Value=11226.000000
# Every 5th Minute Entry=269, Predicted_Value=11689.224904, Expected_Value=11084.000000
# Every 5th Minute Entry=270, Predicted_Value=11499.299546, Expected_Value=11092.000000
# Every 5th Minute Entry=271, Predicted_Value=11446.262760, Expected_Value=11083.000000
# Every 5th Minute Entry=272, Predicted_Value=11362.605374, Expected_Value=11091.000000
# Every 5th Minute Entry=273, Predicted_Value=11280.935039, Expected_Value=11099.000000
# Every 5th Minute Entry=274, Predicted_Value=11188.074450, Expected_Value=11144.000000
# Every 5th Minute Entry=275, Predicted_Value=11125.068035, Expected_Value=11347.000000
# Every 5th Minute Entry=276, Predicted_Value=11213.535831, Expected_Value=11559.000000
# Every 5th Minute Entry=277, Predicted_Value=11303.415548, Expected_Value=11736.000000
# Every 5th Minute Entry=278, Predicted_Value=11348.508071, Expected_Value=11992.000000
# Every 5th Minute Entry=279, Predicted_Value=11469.689901, Expected_Value=12364.000000
# Every 5th Minute Entry=280, Predicted_Value=11714.788875, Expected_Value=12740.000000
# Every 5th Minute Entry=281, Predicted_Value=11982.803110, Expected_Value=12928.000000
# Every 5th Minute Entry=282, Predicted_Value=12090.239198, Expected_Value=12788.000000
# Every 5th Minute Entry=283, Predicted_Value=11901.383841, Expected_Value=12365.000000
# Every 5th Minute Entry=284, Predicted_Value=11464.978460, Expected_Value=11827.000000
# Every 5th Minute Entry=285, Predicted_Value=10947.088188, Expected_Value=11485.000000
# Every 5th Minute Entry=286, Predicted_Value=10653.827599, Expected_Value=11337.000000
# Every 5th Minute Entry=287, Predicted_Value=10579.047361, Expected_Value=11216.000000
# Every 5th Minute Entry=288, Predicted_Value=10552.375756, Expected_Value=11113.000000
# Every 5th Minute Entry=289, Predicted_Value=10561.866642, Expected_Value=11088.000000
# Every 5th Minute Entry=290, Predicted_Value=10664.133064, Expected_Value=11136.000000
# Every 5th Minute Entry=291, Predicted_Value=10849.398806, Expected_Value=11157.000000
# Every 5th Minute Entry=292, Predicted_Value=11011.467366, Expected_Value=11170.000000
# Every 5th Minute Entry=293, Predicted_Value=11162.061402, Expected_Value=11199.000000
# Every 5th Minute Entry=294, Predicted_Value=11317.640648, Expected_Value=11325.000000
# Every 5th Minute Entry=295, Predicted_Value=11553.350370, Expected_Value=11609.000000
# Every 5th Minute Entry=296, Predicted_Value=11927.900240, Expected_Value=11980.000000
# Every 5th Minute Entry=297, Predicted_Value=12371.863209, Expected_Value=12145.000000
# Every 5th Minute Entry=298, Predicted_Value=12595.895063, Expected_Value=11985.000000
# Every 5th Minute Entry=299, Predicted_Value=12484.427372, Expected_Value=11590.000000
# Every 5th Minute Entry=300, Predicted_Value=12129.808710, Expected_Value=11418.000000
# Every 5th Minute Entry=301, Predicted_Value=11986.864247, Expected_Value=11644.000000
# Every 5th Minute Entry=302, Predicted_Value=12232.030835, Expected_Value=12020.000000
# Every 5th Minute Entry=303, Predicted_Value=12618.769837, Expected_Value=12254.000000
# Every 5th Minute Entry=304, Predicted_Value=12853.782048, Expected_Value=12230.000000
# Every 5th Minute Entry=305, Predicted_Value=12818.482031, Expected_Value=12082.000000
# Every 5th Minute Entry=306, Predicted_Value=12644.738749, Expected_Value=11935.000000
# Every 5th Minute Entry=307, Predicted_Value=12456.206008, Expected_Value=11840.000000
# Every 5th Minute Entry=308, Predicted_Value=12303.433497, Expected_Value=11780.000000
# Every 5th Minute Entry=309, Predicted_Value=12169.579895, Expected_Value=11720.000000
# Every 5th Minute Entry=310, Predicted_Value=12016.812469, Expected_Value=11677.000000
# Every 5th Minute Entry=311, Predicted_Value=11866.772825, Expected_Value=11706.000000
# Every 5th Minute Entry=312, Predicted_Value=11781.325979, Expected_Value=11744.000000
# Every 5th Minute Entry=313, Predicted_Value=11697.077272, Expected_Value=11756.000000
# Every 5th Minute Entry=314, Predicted_Value=11577.637776, Expected_Value=11698.000000
# Every 5th Minute Entry=315, Predicted_Value=11380.427229, Expected_Value=11596.000000
# Every 5th Minute Entry=316, Predicted_Value=11127.618074, Expected_Value=11414.000000
# Every 5th Minute Entry=317, Predicted_Value=10790.765376, Expected_Value=11188.000000
# Every 5th Minute Entry=318, Predicted_Value=10421.307439, Expected_Value=10882.000000
# Every 5th Minute Entry=319, Predicted_Value=9997.756876, Expected_Value=10523.000000
# Every 5th Minute Entry=320, Predicted_Value=9556.415562, Expected_Value=10208.000000
# Every 5th Minute Entry=321, Predicted_Value=9199.252184, Expected_Value=9919.000000
# Every 5th Minute Entry=322, Predicted_Value=8908.939893, Expected_Value=9612.000000
# Every 5th Minute Entry=323, Predicted_Value=8635.483491, Expected_Value=9267.000000
# Every 5th Minute Entry=324, Predicted_Value=8352.429738, Expected_Value=8885.000000
# Every 5th Minute Entry=325, Predicted_Value=8057.113848, Expected_Value=8494.000000
# Every 5th Minute Entry=326, Predicted_Value=7774.984119, Expected_Value=8148.000000
# Every 5th Minute Entry=327, Predicted_Value=7557.643663, Expected_Value=7828.000000
# Every 5th Minute Entry=328, Predicted_Value=7382.502121, Expected_Value=7509.000000
# Every 5th Minute Entry=329, Predicted_Value=7218.901976, Expected_Value=7243.000000
# Every 5th Minute Entry=330, Predicted_Value=7111.366237, Expected_Value=6995.000000
# Every 5th Minute Entry=331, Predicted_Value=7015.687993, Expected_Value=6746.000000
# Every 5th Minute Entry=332, Predicted_Value=6903.602252, Expected_Value=6446.000000
# Every 5th Minute Entry=333, Predicted_Value=6718.712863, Expected_Value=6213.000000
# Every 5th Minute Entry=334, Predicted_Value=6577.788476, Expected_Value=5993.000000
# Every 5th Minute Entry=335, Predicted_Value=6430.136764, Expected_Value=5746.000000
# Every 5th Minute Entry=336, Predicted_Value=6241.103734, Expected_Value=5455.000000
# Every 5th Minute Entry=337, Predicted_Value=5998.409174, Expected_Value=5108.000000
# Every 5th Minute Entry=338, Predicted_Value=5692.896088, Expected_Value=4788.000000
# Every 5th Minute Entry=339, Predicted_Value=5404.708277, Expected_Value=4533.000000
# Every 5th Minute Entry=340, Predicted_Value=5170.680479, Expected_Value=4313.000000
# Every 5th Minute Entry=341, Predicted_Value=4961.887739, Expected_Value=4114.000000
# Every 5th Minute Entry=342, Predicted_Value=4763.374106, Expected_Value=3960.000000
# Every 5th Minute Entry=343, Predicted_Value=4596.160920, Expected_Value=3831.000000
# Every 5th Minute Entry=344, Predicted_Value=4437.432728, Expected_Value=3680.000000
# Every 5th Minute Entry=345, Predicted_Value=4238.433662, Expected_Value=3529.000000
# Every 5th Minute Entry=346, Predicted_Value=4020.819693, Expected_Value=3388.000000
# Every 5th Minute Entry=347, Predicted_Value=3792.093446, Expected_Value=3274.000000
# Every 5th Minute Entry=348, Predicted_Value=3571.728665, Expected_Value=3209.000000
# Every 5th Minute Entry=349, Predicted_Value=3390.733660, Expected_Value=3193.000000
# Every 5th Minute Entry=350, Predicted_Value=3251.425976, Expected_Value=3176.000000
# Every 5th Minute Entry=351, Predicted_Value=3101.235250, Expected_Value=3138.000000
# Every 5th Minute Entry=352, Predicted_Value=2919.202330, Expected_Value=3057.000000
# Every 5th Minute Entry=353, Predicted_Value=2685.209079, Expected_Value=2959.000000
# Every 5th Minute Entry=354, Predicted_Value=2422.819962, Expected_Value=2867.000000
# Every 5th Minute Entry=355, Predicted_Value=2162.950689, Expected_Value=2790.000000
# Every 5th Minute Entry=356, Predicted_Value=1934.122201, Expected_Value=2758.000000
# Every 5th Minute Entry=357, Predicted_Value=1782.494985, Expected_Value=2752.000000
# Every 5th Minute Entry=358, Predicted_Value=1697.616159, Expected_Value=2693.000000
# Every 5th Minute Entry=359, Predicted_Value=1605.541205, Expected_Value=2590.000000
# Every 5th Minute Entry=360, Predicted_Value=1512.297038, Expected_Value=2530.000000
# Every 5th Minute Entry=361, Predicted_Value=1496.273595, Expected_Value=2509.000000
# Every 5th Minute Entry=362, Predicted_Value=1546.865250, Expected_Value=2645.000000
# Every 5th Minute Entry=363, Predicted_Value=1779.105544, Expected_Value=2815.000000
# Every 5th Minute Entry=364, Predicted_Value=2068.417166, Expected_Value=2875.000000
# Every 5th Minute Entry=365, Predicted_Value=2268.627834, Expected_Value=2843.000000
# Every 5th Minute Entry=366, Predicted_Value=2393.795815, Expected_Value=3016.000000
# Every 5th Minute Entry=367, Predicted_Value=2734.627101, Expected_Value=3498.000000
# Every 5th Minute Entry=368, Predicted_Value=3386.306793, Expected_Value=3270.000000
# Every 5th Minute Entry=369, Predicted_Value=3319.113721, Expected_Value=3345.000000
# Every 5th Minute Entry=370, Predicted_Value=3535.778687, Expected_Value=3661.000000
# Every 5th Minute Entry=371, Predicted_Value=3968.082385, Expected_Value=3772.000000
# Every 5th Minute Entry=372, Predicted_Value=4169.945587, Expected_Value=3392.000000
# Every 5th Minute Entry=373, Predicted_Value=3860.154057, Expected_Value=3213.000000
# Every 5th Minute Entry=374, Predicted_Value=3737.513570, Expected_Value=3328.000000
# Every 5th Minute Entry=375, Predicted_Value=3899.835786, Expected_Value=2963.000000
# Every 5th Minute Entry=376, Predicted_Value=3573.475390, Expected_Value=2909.000000
# Every 5th Minute Entry=377, Predicted_Value=3547.175183, Expected_Value=2687.000000
# Every 5th Minute Entry=378, Predicted_Value=3346.335164, Expected_Value=2813.000000
# Every 5th Minute Entry=379, Predicted_Value=3489.579692, Expected_Value=2455.000000
# Every 5th Minute Entry=380, Predicted_Value=3135.993327, Expected_Value=2347.000000
# Every 5th Minute Entry=381, Predicted_Value=3013.585286, Expected_Value=2127.000000
# Every 5th Minute Entry=382, Predicted_Value=2759.906749, Expected_Value=2368.000000
# Every 5th Minute Entry=383, Predicted_Value=2947.250607, Expected_Value=2119.000000
# Every 5th Minute Entry=384, Predicted_Value=2624.252017, Expected_Value=2061.000000
# Every 5th Minute Entry=385, Predicted_Value=2468.128092, Expected_Value=2062.000000
# Every 5th Minute Entry=386, Predicted_Value=2353.666330, Expected_Value=1700.000000
# Every 5th Minute Entry=387, Predicted_Value=1869.901947, Expected_Value=1550.000000
# Every 5th Minute Entry=388, Predicted_Value=1590.292636, Expected_Value=1508.000000
# Every 5th Minute Entry=389, Predicted_Value=1407.356476, Expected_Value=1215.000000
# Every 5th Minute Entry=390, Predicted_Value=961.875928, Expected_Value=1239.000000
# Every 5th Minute Entry=391, Predicted_Value=824.019410, Expected_Value=1216.000000
# Every 5th Minute Entry=392, Predicted_Value=627.644565, Expected_Value=1215.000000
# Every 5th Minute Entry=393, Predicted_Value=452.152881, Expected_Value=1069.000000
# Every 5th Minute Entry=394, Predicted_Value=152.758786, Expected_Value=842.000000
# Every 5th Minute Entry=395, Predicted_Value=-190.731254, Expected_Value=861.000000
# Every 5th Minute Entry=396, Predicted_Value=-244.592135, Expected_Value=833.000000
# Every 5th Minute Entry=397, Predicted_Value=-297.016169, Expected_Value=726.000000
# Every 5th Minute Entry=398, Predicted_Value=-385.841751, Expected_Value=565.000000
# Every 5th Minute Entry=399, Predicted_Value=-495.916587, Expected_Value=459.000000
# Every 5th Minute Entry=400, Predicted_Value=-523.755525, Expected_Value=439.000000
# Every 5th Minute Entry=401, Predicted_Value=-440.613885, Expected_Value=343.000000
# Every 5th Minute Entry=402, Predicted_Value=-410.288727, Expected_Value=296.000000
# Every 5th Minute Entry=403, Predicted_Value=-310.322254, Expected_Value=247.000000
# Every 5th Minute Entry=404, Predicted_Value=-195.412824, Expected_Value=249.000000
# Every 5th Minute Entry=405, Predicted_Value=-18.763894, Expected_Value=332.000000
# Every 5th Minute Entry=406, Predicted_Value=239.964440, Expected_Value=479.000000
# Every 5th Minute Entry=407, Predicted_Value=551.894309, Expected_Value=476.000000
# Every 5th Minute Entry=408, Predicted_Value=692.054540, Expected_Value=374.000000
# Every 5th Minute Entry=409, Predicted_Value=705.531321, Expected_Value=400.000000
# Every 5th Minute Entry=410, Predicted_Value=820.318476, Expected_Value=505.000000
# Every 5th Minute Entry=411, Predicted_Value=993.400933, Expected_Value=541.000000
# Every 5th Minute Entry=412, Predicted_Value=1083.793057, Expected_Value=485.000000
# Every 5th Minute Entry=413, Predicted_Value=1070.876442, Expected_Value=380.000000
# Every 5th Minute Entry=414, Predicted_Value=998.002458, Expected_Value=309.000000
# Every 5th Minute Entry=415, Predicted_Value=952.094951, Expected_Value=333.000000
# Every 5th Minute Entry=416, Predicted_Value=997.137218, Expected_Value=355.000000
# Every 5th Minute Entry=417, Predicted_Value=1039.045199, Expected_Value=320.000000
# Every 5th Minute Entry=418, Predicted_Value=1016.293436, Expected_Value=204.000000
# Every 5th Minute Entry=419, Predicted_Value=887.601069, Expected_Value=148.000000
# Every 5th Minute Entry=420, Predicted_Value=794.436247, Expected_Value=88.000000
# Every 5th Minute Entry=421, Predicted_Value=675.943488, Expected_Value=77.000000
# Every 5th Minute Entry=422, Predicted_Value=583.608258, Expected_Value=67.000000
# Every 5th Minute Entry=423, Predicted_Value=468.862529, Expected_Value=57.000000
# Every 5th Minute Entry=424, Predicted_Value=340.626171, Expected_Value=43.000000
# Every 5th Minute Entry=425, Predicted_Value=201.746366, Expected_Value=28.000000
# Every 5th Minute Entry=426, Predicted_Value=52.466297, Expected_Value=18.000000
# Every 5th Minute Entry=427, Predicted_Value=-103.580556, Expected_Value=11.000000
# Every 5th Minute Entry=428, Predicted_Value=-268.125970, Expected_Value=9.000000
# Every 5th Minute Entry=429, Predicted_Value=-436.951726, Expected_Value=6.000000
# Every 5th Minute Entry=430, Predicted_Value=-618.344838, Expected_Value=0.000000
# Every 5th Minute Entry=431, Predicted_Value=-800.526798, Expected_Value=0.000000
# Every 5th Minute Entry=432, Predicted_Value=-951.674847, Expected_Value=0.000000
# Every 5th Minute Entry=433, Predicted_Value=-1062.947525, Expected_Value=0.000000
# Every 5th Minute Entry=434, Predicted_Value=-1129.327117, Expected_Value=0.000000
# Every 5th Minute Entry=435, Predicted_Value=-1147.263238, Expected_Value=0.000000
# Every 5th Minute Entry=436, Predicted_Value=-1123.581481, Expected_Value=0.000000
# Every 5th Minute Entry=437, Predicted_Value=-1067.931670, Expected_Value=0.000000
# Every 5th Minute Entry=438, Predicted_Value=-985.366635, Expected_Value=0.000000
# Every 5th Minute Entry=439, Predicted_Value=-877.847747, Expected_Value=0.000000
# Every 5th Minute Entry=440, Predicted_Value=-747.437965, Expected_Value=0.000000
# Every 5th Minute Entry=441, Predicted_Value=-596.984711, Expected_Value=0.000000
# Every 5th Minute Entry=442, Predicted_Value=-430.240670, Expected_Value=0.000000
# Every 5th Minute Entry=443, Predicted_Value=-253.127274, Expected_Value=0.000000
# Every 5th Minute Entry=444, Predicted_Value=-75.304728, Expected_Value=0.000000
# Every 5th Minute Entry=445, Predicted_Value=90.747500, Expected_Value=0.000000
# Every 5th Minute Entry=446, Predicted_Value=233.646356, Expected_Value=0.000000
# Every 5th Minute Entry=447, Predicted_Value=347.619865, Expected_Value=0.000000
# Every 5th Minute Entry=448, Predicted_Value=434.267037, Expected_Value=0.000000
# Every 5th Minute Entry=449, Predicted_Value=500.573197, Expected_Value=0.000000
# Every 5th Minute Entry=450, Predicted_Value=552.819984, Expected_Value=0.000000
# Every 5th Minute Entry=451, Predicted_Value=591.833984, Expected_Value=0.000000
# Every 5th Minute Entry=452, Predicted_Value=621.868053, Expected_Value=0.000000
# Every 5th Minute Entry=453, Predicted_Value=646.401187, Expected_Value=0.000000
# Every 5th Minute Entry=454, Predicted_Value=667.262357, Expected_Value=0.000000
# Every 5th Minute Entry=455, Predicted_Value=687.803405, Expected_Value=0.000000
# Every 5th Minute Entry=456, Predicted_Value=701.989878, Expected_Value=0.000000
# Every 5th Minute Entry=457, Predicted_Value=689.125856, Expected_Value=0.000000
# Every 5th Minute Entry=458, Predicted_Value=649.451238, Expected_Value=0.000000
# Every 5th Minute Entry=459, Predicted_Value=587.606471, Expected_Value=0.000000
# Every 5th Minute Entry=460, Predicted_Value=501.655031, Expected_Value=0.000000
# Every 5th Minute Entry=461, Predicted_Value=393.137459, Expected_Value=0.000000
# Every 5th Minute Entry=462, Predicted_Value=273.450613, Expected_Value=0.000000
# Every 5th Minute Entry=463, Predicted_Value=146.902947, Expected_Value=0.000000
# Every 5th Minute Entry=464, Predicted_Value=10.148805, Expected_Value=0.000000
# Every 5th Minute Entry=465, Predicted_Value=-138.598603, Expected_Value=0.000000
# Every 5th Minute Entry=466, Predicted_Value=-298.809898, Expected_Value=0.000000
# Every 5th Minute Entry=467, Predicted_Value=-467.955022, Expected_Value=0.000000
# Every 5th Minute Entry=468, Predicted_Value=-648.851801, Expected_Value=0.000000
# Every 5th Minute Entry=469, Predicted_Value=-824.709002, Expected_Value=0.000000
# Every 5th Minute Entry=470, Predicted_Value=-972.873366, Expected_Value=0.000000
# Every 5th Minute Entry=471, Predicted_Value=-1079.520559, Expected_Value=0.000000
# Every 5th Minute Entry=472, Predicted_Value=-1140.189851, Expected_Value=0.000000
# Every 5th Minute Entry=473, Predicted_Value=-1153.026542, Expected_Value=0.000000
# Every 5th Minute Entry=474, Predicted_Value=-1125.320013, Expected_Value=0.000000
# Every 5th Minute Entry=475, Predicted_Value=-1066.229357, Expected_Value=0.000000
# Every 5th Minute Entry=476, Predicted_Value=-980.657669, Expected_Value=0.000000
# Every 5th Minute Entry=477, Predicted_Value=-870.267067, Expected_Value=0.000000
# Every 5th Minute Entry=478, Predicted_Value=-737.138841, Expected_Value=0.000000
# Every 5th Minute Entry=479, Predicted_Value=-584.137308, Expected_Value=0.000000
# Every 5th Minute Entry=480, Predicted_Value=-415.474963, Expected_Value=0.000000
# Every 5th Minute Entry=481, Predicted_Value=-237.207183, Expected_Value=0.000000
# Every 5th Minute Entry=482, Predicted_Value=-59.039118, Expected_Value=0.000000
# Every 5th Minute Entry=483, Predicted_Value=106.319090, Expected_Value=0.000000
# Every 5th Minute Entry=484, Predicted_Value=247.523141, Expected_Value=0.000000
# Every 5th Minute Entry=485, Predicted_Value=359.253641, Expected_Value=0.000000
# Every 5th Minute Entry=486, Predicted_Value=443.724667, Expected_Value=0.000000
# Every 5th Minute Entry=487, Predicted_Value=508.490121, Expected_Value=0.000000
# Every 5th Minute Entry=488, Predicted_Value=559.288960, Expected_Value=0.000000
# Every 5th Minute Entry=489, Predicted_Value=595.945937, Expected_Value=0.000000
# Every 5th Minute Entry=490, Predicted_Value=624.869572, Expected_Value=2.000000
# Every 5th Minute Entry=491, Predicted_Value=650.889229, Expected_Value=7.000000
# Every 5th Minute Entry=492, Predicted_Value=676.592933, Expected_Value=15.000000
# Every 5th Minute Entry=493, Predicted_Value=705.202997, Expected_Value=27.000000
# Every 5th Minute Entry=494, Predicted_Value=731.153491, Expected_Value=46.000000
# Every 5th Minute Entry=495, Predicted_Value=735.637952, Expected_Value=64.000000
# Every 5th Minute Entry=496, Predicted_Value=711.556786, Expected_Value=82.000000
# Every 5th Minute Entry=497, Predicted_Value=665.150931, Expected_Value=197.000000
# Every 5th Minute Entry=498, Predicted_Value=690.986067, Expected_Value=331.000000
# Every 5th Minute Entry=499, Predicted_Value=714.008058, Expected_Value=433.000000
# Every 5th Minute Entry=500, Predicted_Value=695.443001, Expected_Value=515.000000
# Every 5th Minute Entry=501, Predicted_Value=649.834152, Expected_Value=547.000000
# Every 5th Minute Entry=502, Predicted_Value=543.487569, Expected_Value=498.000000
# Every 5th Minute Entry=503, Predicted_Value=344.005052, Expected_Value=451.000000
# Every 5th Minute Entry=504, Predicted_Value=135.142792, Expected_Value=535.000000
# Every 5th Minute Entry=505, Predicted_Value=48.793041, Expected_Value=749.000000
# Every 5th Minute Entry=506, Predicted_Value=80.443620, Expected_Value=1004.000000
# Every 5th Minute Entry=507, Predicted_Value=160.839855, Expected_Value=1227.000000
# Every 5th Minute Entry=508, Predicted_Value=239.004586, Expected_Value=1435.000000
# Every 5th Minute Entry=509, Predicted_Value=344.683405, Expected_Value=1627.000000
# Every 5th Minute Entry=510, Predicted_Value=481.060979, Expected_Value=1804.000000
# Every 5th Minute Entry=511, Predicted_Value=649.677067, Expected_Value=1958.000000
# Every 5th Minute Entry=512, Predicted_Value=834.817596, Expected_Value=2146.000000
# Every 5th Minute Entry=513, Predicted_Value=1084.768481, Expected_Value=2395.000000
# Every 5th Minute Entry=514, Predicted_Value=1421.888116, Expected_Value=2687.000000
# Every 5th Minute Entry=515, Predicted_Value=1826.720879, Expected_Value=3088.000000
# Every 5th Minute Entry=516, Predicted_Value=2363.092721, Expected_Value=3532.000000
# Every 5th Minute Entry=517, Predicted_Value=2962.081022, Expected_Value=3987.000000
# Every 5th Minute Entry=518, Predicted_Value=3587.175691, Expected_Value=4558.000000
# Every 5th Minute Entry=519, Predicted_Value=4337.119492, Expected_Value=5230.000000
# Every 5th Minute Entry=520, Predicted_Value=5186.975386, Expected_Value=15706.000000
# Every 5th Minute Entry=521, Predicted_Value=15826.904693, Expected_Value=15667.000000
# Every 5th Minute Entry=522, Predicted_Value=15926.815879, Expected_Value=15614.000000
# Every 5th Minute Entry=523, Predicted_Value=15983.013118, Expected_Value=15635.000000
# Every 5th Minute Entry=524, Predicted_Value=16086.332291, Expected_Value=15720.000000
# Every 5th Minute Entry=525, Predicted_Value=16234.688501, Expected_Value=15822.000000
# Every 5th Minute Entry=526, Predicted_Value=16386.340519, Expected_Value=15959.000000
# Every 5th Minute Entry=527, Predicted_Value=16558.348630, Expected_Value=15944.000000
# Every 5th Minute Entry=528, Predicted_Value=16571.554060, Expected_Value=15878.000000
# Every 5th Minute Entry=529, Predicted_Value=16529.058861, Expected_Value=15840.000000
# Every 5th Minute Entry=530, Predicted_Value=16511.614816, Expected_Value=15866.000000
# Every 5th Minute Entry=531, Predicted_Value=16558.108160, Expected_Value=15910.000000
# Every 5th Minute Entry=532, Predicted_Value=16615.017678, Expected_Value=15926.000000
# Every 5th Minute Entry=533, Predicted_Value=16614.158477, Expected_Value=15937.000000
# Every 5th Minute Entry=534, Predicted_Value=16580.643211, Expected_Value=15943.000000
# Every 5th Minute Entry=535, Predicted_Value=16519.999482, Expected_Value=15973.000000
# Every 5th Minute Entry=536, Predicted_Value=16458.224225, Expected_Value=16000.000000
# Every 5th Minute Entry=537, Predicted_Value=16372.340887, Expected_Value=16000.000000
# Every 5th Minute Entry=538, Predicted_Value=16251.091968, Expected_Value=15990.000000
# Every 5th Minute Entry=539, Predicted_Value=16112.611423, Expected_Value=15895.000000
# Every 5th Minute Entry=540, Predicted_Value=15877.986450, Expected_Value=15766.000000
# Every 5th Minute Entry=541, Predicted_Value=15597.155533, Expected_Value=15662.000000
# Every 5th Minute Entry=542, Predicted_Value=15330.075836, Expected_Value=15538.000000
# Every 5th Minute Entry=543, Predicted_Value=15034.999488, Expected_Value=15500.000000
# Every 5th Minute Entry=544, Predicted_Value=14813.647408, Expected_Value=15359.000000
# Every 5th Minute Entry=545, Predicted_Value=14499.745182, Expected_Value=15135.000000
# Every 5th Minute Entry=546, Predicted_Value=14134.405970, Expected_Value=14927.000000
# Every 5th Minute Entry=547, Predicted_Value=13828.274316, Expected_Value=14952.000000
# Every 5th Minute Entry=548, Predicted_Value=13802.398401, Expected_Value=14794.000000
# Every 5th Minute Entry=549, Predicted_Value=13640.177956, Expected_Value=14835.000000
# Every 5th Minute Entry=550, Predicted_Value=13715.504688, Expected_Value=15268.000000
# Every 5th Minute Entry=551, Predicted_Value=14213.083910, Expected_Value=15669.000000
# Every 5th Minute Entry=552, Predicted_Value=14704.573930, Expected_Value=15807.000000
# Every 5th Minute Entry=553, Predicted_Value=14957.686308, Expected_Value=15878.000000
# Every 5th Minute Entry=554, Predicted_Value=15166.112498, Expected_Value=15940.000000
# Every 5th Minute Entry=555, Predicted_Value=15384.850704, Expected_Value=16000.000000
# Every 5th Minute Entry=556, Predicted_Value=15616.157399, Expected_Value=16000.000000
# Every 5th Minute Entry=557, Predicted_Value=15795.557256, Expected_Value=16000.000000
# Every 5th Minute Entry=558, Predicted_Value=15972.806364, Expected_Value=16000.000000
# Every 5th Minute Entry=559, Predicted_Value=16134.987974, Expected_Value=15834.000000
# Every 5th Minute Entry=560, Predicted_Value=16105.364849, Expected_Value=15724.000000
# Every 5th Minute Entry=561, Predicted_Value=16101.940763, Expected_Value=15645.000000
# Every 5th Minute Entry=562, Predicted_Value=16103.164013, Expected_Value=15404.000000
# Every 5th Minute Entry=563, Predicted_Value=15923.953843, Expected_Value=15277.000000
# Every 5th Minute Entry=564, Predicted_Value=15845.136933, Expected_Value=15535.000000
# Every 5th Minute Entry=565, Predicted_Value=16137.178051, Expected_Value=15767.000000
# Every 5th Minute Entry=566, Predicted_Value=16397.114927, Expected_Value=15848.000000
# Every 5th Minute Entry=567, Predicted_Value=16501.106473, Expected_Value=15905.000000
# Every 5th Minute Entry=568, Predicted_Value=16578.515121, Expected_Value=16000.000000
# Every 5th Minute Entry=569, Predicted_Value=16693.583550, Expected_Value=16000.000000
# Every 5th Minute Entry=570, Predicted_Value=16704.527942, Expected_Value=16000.000000
# Every 5th Minute Entry=571, Predicted_Value=16685.524177, Expected_Value=16000.000000
# Every 5th Minute Entry=572, Predicted_Value=16638.986587, Expected_Value=16000.000000
# Every 5th Minute Entry=573, Predicted_Value=16570.305073, Expected_Value=16000.000000
# Every 5th Minute Entry=574, Predicted_Value=16476.117581, Expected_Value=16000.000000
# Every 5th Minute Entry=575, Predicted_Value=16361.510067, Expected_Value=16000.000000
# Every 5th Minute Entry=576, Predicted_Value=16239.609419, Expected_Value=16000.000000

# %%
from sklearn.metrics import mean_squared_error
print("Root mean squared error: %.3f" % sqrt(mean_squared_error(Expected_Val, Y_pred)))
# Out:
# Root mean squared error: 239.609

# %%
# Plot between the predicted power by the system and the number of hours
from matplotlib import pyplot
pyplot.figure(figsize=(20,8))
pyplot.plot(Expectation_plot, label="True values")
pyplot.plot(Pred_plot, label="Predicted values")
pyplot.xlabel("Number of hours of future prediction/12 units=1 hour")
pyplot.ylabel("Power generated by system in (kW)")
pyplot.legend()
pyplot.show()

# %%
# Calculating Mean Absolute Percent Error - Performance Evaluation
from sklearn.metrics import mean_squared_error
mape = (np.mean(np.abs((Expectation - Prediction) / Expectation))*100)
print("Calculation of the Mean Absolute Percent Error: ", mape )
# Out:
# Calculation of the Mean Absolute Percent Error:  147.5794538615494
