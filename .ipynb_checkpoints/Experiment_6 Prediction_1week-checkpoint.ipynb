# %%
#Installing all the necessary packages in order to undergo the prediction
import numpy as np
from math import sqrt
import pandas as pd
from pandas import Series , concat
from pandas import DataFrame , datetime
from pandas import read_csv
import pandas as pd
from keras.models import Sequential
# Out:
# Using TensorFlow backend.

# %%
#Loading the data set
dataset = pd.read_csv('C:/Users/gurun/Desktop/ProjectCPS/EXP3/DPPdataset.csv',index_col="DATETIME")
dataset.head()
# Out:
#                air temp degree  Air density  wind speed at 100m (m/s)  \
# DATETIME
# 1/1/2007 0:00            2.430        1.223                    11.673
# 1/1/2007 0:05            2.387        1.224                    11.395
# 1/1/2007 0:10            2.336        1.224                    11.468
# 1/1/2007 0:15            2.278        1.224                    11.636
# 1/1/2007 0:20            2.192        1.225                    11.727
#
#                wind direction at 100m (deg)  Power (KW)
# DATETIME
# 1/1/2007 0:00                       244.189       15701
# 1/1/2007 0:05                       244.755       15498
# 1/1/2007 0:10                       245.644       15568
# 1/1/2007 0:15                       246.863       15691
# 1/1/2007 0:20                       247.287       15719

# %%
# Framing the the sequence as a supervised learning problem
def timeseries_to_supervised(data, lag=1):
    df_set = DataFrame(data)
    columns = [df_set.shift(i) for i in range(1, lag+1)]
    columns.append(df_set)
    df_set = concat(columns, axis=1)
    df_set.fillna(0, inplace=True)
    return df_set

# %%
# creating a differenced series
def difference(Data_Set, interval=1):
    diff = list()
    for i in range(interval, len(Data_Set)):
        value = Data_Set[i] - Data_Set[i - interval]
        diff.append(value)
    return Series(diff)
# inverting the differenced value
def inverse_difference(history, Y_pred, interval=1):
    return Y_pred + history[-interval]

# %%
# Dropping all the features which we will not be using
del dataset['air temp degree']
del dataset['Air density']
del dataset['wind speed at 100m (m/s)']
del dataset['wind direction at 100m (deg)']
for i in range(0,15):
  dataset = dataset[:-1]
dataset.tail()
# Out:
#                   Power (KW)
# DATETIME
# 12/31/2007 22:20       16000
# 12/31/2007 22:25       16000
# 12/31/2007 22:30       16000
# 12/31/2007 22:35       16000
# 12/31/2007 22:40       16000

# %%
# Performing scaling on the train data to [-1, 1]
from sklearn.preprocessing import MinMaxScaler
def scale(Xtrain, Xtest):
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler = scaler.fit(Xtrain)
    Xtrain = Xtrain.reshape(Xtrain.shape[0], Xtrain.shape[1])
    Xtrain_scaled = scaler.transform(Xtrain)
    
    
# Performing scaling on the test data to [-1, 1]
    Xtest = Xtest.reshape(Xtest.shape[0], Xtest.shape[1])
    Xtest_scaled = scaler.transform(Xtest)
    return scaler, Xtrain_scaled, Xtest_scaled

# %%
# Performing inverse scaling for a forecasted value
def invert_scale(scaler, X, value):
    np_rowval = [x for x in X] + [value]
    array = np.array(np_rowval)
    array = array.reshape(1, len(array))
    inverted = scaler.inverse_transform(array)
    return inverted[0, -1]

# %%
# Hardcoding all variables
Lag_duration =24
Predict_Value_Size= 2016
Epoch_Size = 6
Batch_Size = 1
Neurons_Size = 10

# %%
# fitting the LSTM model into a Training Data set
from keras.layers import Dense, LSTM
from keras.models import Sequential
def fit_lstm(Xtrain, batch_size, nb_epoch, neurons):
    X, y = Xtrain[:, 0:-1], Xtrain[:, -1]
    X = X.reshape(X.shape[0], 1, X.shape[1])
    
    model = Sequential()
    model.add(LSTM(neurons, batch_input_shape=(Batch_Size, X.shape[1], X.shape[2]), stateful=True))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    for i in range(nb_epoch):
        model.fit(X, y, epochs=1, batch_size=batch_size, verbose=1, shuffle=False)
        model.reset_states()
    return model

# %%
# Variables Required for performing forwad walk validation on the test data set
Prediction = list()
Expectation = list()
Pred_plot = list()
Expectation_plot = list()
Test_Prediction = list()

# %%
# making an one-step forecast
def forecast_lstm(model, batch_size, X):
    X = X.reshape(1, 1, len(X))
    Y_pred = model.predict(X, batch_size=1)
    return Y_pred[0,0]

# %%
# transforming the data into a stationary data set
Raw_val = dataset.values
Different_val = difference(Raw_val, 1)
# transforming the data into a  supervised learning
supervised = timeseries_to_supervised(Different_val, Lag_duration)
supervised_values = supervised.values

# %%
# splitting the dataset into train-sets and test-sets
Xtrain, Xtest = supervised_values[0:-Predict_Value_Size], supervised_values[-Predict_Value_Size:]
# perform scaling on the data
scaler, Xtrain_scaled, Xtest_scaled = scale(Xtrain, Xtest)
# Out:
# C:\Users\gurun\AppData\Local\conda\conda\envs\tensorflow-sessions\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype object was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
# fitting the LSTM model 
lstm_model = fit_lstm(Xtrain_scaled, Batch_Size, Epoch_Size, Neurons_Size)
# Out:
# Epoch 1/1
# 103088/103088 [==============================] - 162s 2ms/step - loss: 0.0012
# Epoch 1/1
# 103088/103088 [==============================] - 155s 2ms/step - loss: 0.0011
# Epoch 1/1
# 103088/103088 [==============================] - 162s 2ms/step - loss: 0.0010
# Epoch 1/1
# 103088/103088 [==============================] - 163s 2ms/step - loss: 0.0010
# Epoch 1/1
# 103088/103088 [==============================] - 164s 2ms/step - loss: 0.0010
# Epoch 1/1
# 103088/103088 [==============================] - 183s 2ms/step - loss: 0.0010

# %%
for i in range(len(Xtest_scaled)):
    # making one-step forecast
    X, y = Xtest_scaled[i, 0:-1], Xtest_scaled[i, -1]
    Y_pred = forecast_lstm(lstm_model, 1, X)
    # Replacing the values of test scaled data with the newly predicted value.
    Test_Prediction = [Y_pred] + Test_Prediction 
    if len(Test_Prediction) > Lag_duration+1:
        Test_Prediction = Test_Prediction[:-1]
    if i+1<len(Xtest_scaled):
        if i+1 > Lag_duration+1:
            Xtest_scaled[i+1] = Test_Prediction
        else:
            Xtest_scaled[i+1] = np.concatenate((Test_Prediction, Xtest_scaled[i+1, i+1:]),axis=0)

    #Performing the invert scaling and invert differencing and store the forecasted values into an array
    Y_pred = invert_scale(scaler, X, Y_pred)
    Y_pred = inverse_difference(Raw_val, Y_pred, len(Xtest_scaled)+1-i)
    Expected_Val = Raw_val[len(Xtrain) + i + 1]
    Pred_plot.append(Y_pred)
    Expectation_plot.append(Expected_Val)
    if Expected_Val != 0:
        Prediction.append(Y_pred)
        Expectation.append(Expected_Val)
    print('Every 5th Minute Entry=%d, Predicted_Value=%f, Expected_Value=%f' % (i+1, Y_pred, Expected_Val))

Expectation = np.array(Expectation)
Prediction = np.array(Prediction)
# Out:
# Every 5th Minute Entry=1, Predicted_Value=705.507940, Expected_Value=683.000000
# Every 5th Minute Entry=2, Predicted_Value=529.635359, Expected_Value=651.000000
# Every 5th Minute Entry=3, Predicted_Value=457.478846, Expected_Value=617.000000
# Every 5th Minute Entry=4, Predicted_Value=441.178878, Expected_Value=586.000000
# Every 5th Minute Entry=5, Predicted_Value=424.154935, Expected_Value=565.000000
# Every 5th Minute Entry=6, Predicted_Value=412.138345, Expected_Value=538.000000
# Every 5th Minute Entry=7, Predicted_Value=395.010897, Expected_Value=475.000000
# Every 5th Minute Entry=8, Predicted_Value=356.157323, Expected_Value=418.000000
# Every 5th Minute Entry=9, Predicted_Value=327.827422, Expected_Value=391.000000
# Every 5th Minute Entry=10, Predicted_Value=328.385982, Expected_Value=371.000000
# Every 5th Minute Entry=11, Predicted_Value=331.200019, Expected_Value=366.000000
# Every 5th Minute Entry=12, Predicted_Value=340.321948, Expected_Value=386.000000
# Every 5th Minute Entry=13, Predicted_Value=368.389713, Expected_Value=424.000000
# Every 5th Minute Entry=14, Predicted_Value=409.930161, Expected_Value=504.000000
# Every 5th Minute Entry=15, Predicted_Value=490.526235, Expected_Value=598.000000
# Every 5th Minute Entry=16, Predicted_Value=588.089431, Expected_Value=716.000000
# Every 5th Minute Entry=17, Predicted_Value=704.705695, Expected_Value=860.000000
# Every 5th Minute Entry=18, Predicted_Value=845.942197, Expected_Value=1061.000000
# Every 5th Minute Entry=19, Predicted_Value=1042.876347, Expected_Value=1199.000000
# Every 5th Minute Entry=20, Predicted_Value=1176.986624, Expected_Value=1350.000000
# Every 5th Minute Entry=21, Predicted_Value=1329.753756, Expected_Value=1431.000000
# Every 5th Minute Entry=22, Predicted_Value=1416.556372, Expected_Value=1434.000000
# Every 5th Minute Entry=23, Predicted_Value=1420.840395, Expected_Value=1445.000000
# Every 5th Minute Entry=24, Predicted_Value=1431.031642, Expected_Value=1475.000000
# Every 5th Minute Entry=25, Predicted_Value=1458.236673, Expected_Value=1483.000000
# Every 5th Minute Entry=26, Predicted_Value=1467.913146, Expected_Value=1563.000000
# Every 5th Minute Entry=27, Predicted_Value=1547.173188, Expected_Value=1705.000000
# Every 5th Minute Entry=28, Predicted_Value=1679.653886, Expected_Value=1797.000000
# Every 5th Minute Entry=29, Predicted_Value=1756.471545, Expected_Value=1781.000000
# Every 5th Minute Entry=30, Predicted_Value=1724.382725, Expected_Value=1711.000000
# Every 5th Minute Entry=31, Predicted_Value=1639.924993, Expected_Value=1687.000000
# Every 5th Minute Entry=32, Predicted_Value=1602.921670, Expected_Value=1729.000000
# Every 5th Minute Entry=33, Predicted_Value=1633.367455, Expected_Value=1802.000000
# Every 5th Minute Entry=34, Predicted_Value=1696.917941, Expected_Value=1797.000000
# Every 5th Minute Entry=35, Predicted_Value=1684.824125, Expected_Value=1854.000000
# Every 5th Minute Entry=36, Predicted_Value=1737.843523, Expected_Value=2038.000000
# Every 5th Minute Entry=37, Predicted_Value=1921.311936, Expected_Value=2313.000000
# Every 5th Minute Entry=38, Predicted_Value=2198.381412, Expected_Value=2573.000000
# Every 5th Minute Entry=39, Predicted_Value=2462.110908, Expected_Value=2529.000000
# Every 5th Minute Entry=40, Predicted_Value=2422.226892, Expected_Value=2517.000000
# Every 5th Minute Entry=41, Predicted_Value=2414.777067, Expected_Value=2707.000000
# Every 5th Minute Entry=42, Predicted_Value=2610.222457, Expected_Value=2793.000000
# Every 5th Minute Entry=43, Predicted_Value=2702.489631, Expected_Value=2831.000000
# Every 5th Minute Entry=44, Predicted_Value=2747.240025, Expected_Value=2859.000000
# Every 5th Minute Entry=45, Predicted_Value=2781.855701, Expected_Value=2940.000000
# Every 5th Minute Entry=46, Predicted_Value=2869.235288, Expected_Value=3093.000000
# Every 5th Minute Entry=47, Predicted_Value=3029.193612, Expected_Value=3169.000000
# Every 5th Minute Entry=48, Predicted_Value=3112.957598, Expected_Value=3170.000000
# Every 5th Minute Entry=49, Predicted_Value=3122.152903, Expected_Value=3121.000000
# Every 5th Minute Entry=50, Predicted_Value=3080.947808, Expected_Value=3067.000000
# Every 5th Minute Entry=51, Predicted_Value=3034.140454, Expected_Value=3099.000000
# Every 5th Minute Entry=52, Predicted_Value=3073.086743, Expected_Value=3196.000000
# Every 5th Minute Entry=53, Predicted_Value=3176.643893, Expected_Value=3249.000000
# Every 5th Minute Entry=54, Predicted_Value=3235.110264, Expected_Value=3296.000000
# Every 5th Minute Entry=55, Predicted_Value=3285.758929, Expected_Value=3409.000000
# Every 5th Minute Entry=56, Predicted_Value=3400.273188, Expected_Value=3559.000000
# Every 5th Minute Entry=57, Predicted_Value=3549.737516, Expected_Value=3737.000000
# Every 5th Minute Entry=58, Predicted_Value=3725.379278, Expected_Value=3921.000000
# Every 5th Minute Entry=59, Predicted_Value=3905.472109, Expected_Value=4106.000000
# Every 5th Minute Entry=60, Predicted_Value=4085.224047, Expected_Value=4277.000000
# Every 5th Minute Entry=61, Predicted_Value=4249.786377, Expected_Value=4405.000000
# Every 5th Minute Entry=62, Predicted_Value=4370.438584, Expected_Value=4512.000000
# Every 5th Minute Entry=63, Predicted_Value=4469.573449, Expected_Value=4676.000000
# Every 5th Minute Entry=64, Predicted_Value=4625.614894, Expected_Value=4825.000000
# Every 5th Minute Entry=65, Predicted_Value=4766.822308, Expected_Value=4974.000000
# Every 5th Minute Entry=66, Predicted_Value=4908.273541, Expected_Value=5173.000000
# Every 5th Minute Entry=67, Predicted_Value=5100.040590, Expected_Value=5386.000000
# Every 5th Minute Entry=68, Predicted_Value=5306.275730, Expected_Value=5585.000000
# Every 5th Minute Entry=69, Predicted_Value=5499.196058, Expected_Value=5812.000000
# Every 5th Minute Entry=70, Predicted_Value=5720.987970, Expected_Value=6025.000000
# Every 5th Minute Entry=71, Predicted_Value=5929.720263, Expected_Value=6145.000000
# Every 5th Minute Entry=72, Predicted_Value=6046.434676, Expected_Value=6243.000000
# Every 5th Minute Entry=73, Predicted_Value=6142.233794, Expected_Value=6356.000000
# Every 5th Minute Entry=74, Predicted_Value=6254.277955, Expected_Value=6500.000000
# Every 5th Minute Entry=75, Predicted_Value=6398.678356, Expected_Value=6786.000000
# Every 5th Minute Entry=76, Predicted_Value=6686.421084, Expected_Value=7080.000000
# Every 5th Minute Entry=77, Predicted_Value=6983.426854, Expected_Value=7312.000000
# Every 5th Minute Entry=78, Predicted_Value=7219.618037, Expected_Value=7516.000000
# Every 5th Minute Entry=79, Predicted_Value=7428.911262, Expected_Value=7658.000000
# Every 5th Minute Entry=80, Predicted_Value=7577.167062, Expected_Value=7792.000000
# Every 5th Minute Entry=81, Predicted_Value=7718.155974, Expected_Value=8006.000000
# Every 5th Minute Entry=82, Predicted_Value=7939.583605, Expected_Value=8302.000000
# Every 5th Minute Entry=83, Predicted_Value=8243.136127, Expected_Value=8552.000000
# Every 5th Minute Entry=84, Predicted_Value=8500.529747, Expected_Value=8730.000000
# Every 5th Minute Entry=85, Predicted_Value=8685.516892, Expected_Value=8943.000000
# Every 5th Minute Entry=86, Predicted_Value=8904.892283, Expected_Value=9329.000000
# Every 5th Minute Entry=87, Predicted_Value=9296.474159, Expected_Value=9659.000000
# Every 5th Minute Entry=88, Predicted_Value=9631.100306, Expected_Value=9925.000000
# Every 5th Minute Entry=89, Predicted_Value=9900.652901, Expected_Value=10208.000000
# Every 5th Minute Entry=90, Predicted_Value=10186.075737, Expected_Value=10508.000000
# Every 5th Minute Entry=91, Predicted_Value=10487.358987, Expected_Value=10784.000000
# Every 5th Minute Entry=92, Predicted_Value=10763.512367, Expected_Value=11088.000000
# Every 5th Minute Entry=93, Predicted_Value=11066.553215, Expected_Value=11304.000000
# Every 5th Minute Entry=94, Predicted_Value=11280.515983, Expected_Value=11501.000000
# Every 5th Minute Entry=95, Predicted_Value=11474.467037, Expected_Value=11770.000000
# Every 5th Minute Entry=96, Predicted_Value=11739.506311, Expected_Value=12039.000000
# Every 5th Minute Entry=97, Predicted_Value=12003.753396, Expected_Value=12425.000000
# Every 5th Minute Entry=98, Predicted_Value=12384.338703, Expected_Value=12760.000000
# Every 5th Minute Entry=99, Predicted_Value=12713.407995, Expected_Value=13010.000000
# Every 5th Minute Entry=100, Predicted_Value=12957.133422, Expected_Value=13210.000000
# Every 5th Minute Entry=101, Predicted_Value=13150.692329, Expected_Value=13371.000000
# Every 5th Minute Entry=102, Predicted_Value=13305.286019, Expected_Value=13557.000000
# Every 5th Minute Entry=103, Predicted_Value=13485.122203, Expected_Value=13741.000000
# Every 5th Minute Entry=104, Predicted_Value=13663.397216, Expected_Value=13938.000000
# Every 5th Minute Entry=105, Predicted_Value=13855.294143, Expected_Value=14078.000000
# Every 5th Minute Entry=106, Predicted_Value=13990.981382, Expected_Value=14226.000000
# Every 5th Minute Entry=107, Predicted_Value=14135.603038, Expected_Value=14412.000000
# Every 5th Minute Entry=108, Predicted_Value=14319.269536, Expected_Value=14566.000000
# Every 5th Minute Entry=109, Predicted_Value=14472.048566, Expected_Value=14719.000000
# Every 5th Minute Entry=110, Predicted_Value=14624.964311, Expected_Value=14794.000000
# Every 5th Minute Entry=111, Predicted_Value=14701.000982, Expected_Value=14848.000000
# Every 5th Minute Entry=112, Predicted_Value=14757.106788, Expected_Value=14942.000000
# Every 5th Minute Entry=113, Predicted_Value=14854.196812, Expected_Value=15006.000000
# Every 5th Minute Entry=114, Predicted_Value=14922.153673, Expected_Value=15063.000000
# Every 5th Minute Entry=115, Predicted_Value=14983.833045, Expected_Value=15115.000000
# Every 5th Minute Entry=116, Predicted_Value=15041.071499, Expected_Value=15061.000000
# Every 5th Minute Entry=117, Predicted_Value=14992.693901, Expected_Value=15034.000000
# Every 5th Minute Entry=118, Predicted_Value=14971.521584, Expected_Value=15045.000000
# Every 5th Minute Entry=119, Predicted_Value=14988.373891, Expected_Value=14884.000000
# Every 5th Minute Entry=120, Predicted_Value=14833.074695, Expected_Value=14798.000000
# Every 5th Minute Entry=121, Predicted_Value=14752.443671, Expected_Value=14760.000000
# Every 5th Minute Entry=122, Predicted_Value=14719.323575, Expected_Value=14373.000000
# Every 5th Minute Entry=123, Predicted_Value=14336.581565, Expected_Value=14137.000000
# Every 5th Minute Entry=124, Predicted_Value=14104.103352, Expected_Value=14055.000000
# Every 5th Minute Entry=125, Predicted_Value=14024.794521, Expected_Value=13349.000000
# Every 5th Minute Entry=126, Predicted_Value=13320.584842, Expected_Value=12952.000000
# Every 5th Minute Entry=127, Predicted_Value=12924.429704, Expected_Value=12747.000000
# Every 5th Minute Entry=128, Predicted_Value=12719.313647, Expected_Value=13017.000000
# Every 5th Minute Entry=129, Predicted_Value=12988.251138, Expected_Value=12927.000000
# Every 5th Minute Entry=130, Predicted_Value=12896.284799, Expected_Value=12738.000000
# Every 5th Minute Entry=131, Predicted_Value=12704.482652, Expected_Value=12734.000000
# Every 5th Minute Entry=132, Predicted_Value=12696.936904, Expected_Value=12629.000000
# Every 5th Minute Entry=133, Predicted_Value=12587.761512, Expected_Value=12472.000000
# Every 5th Minute Entry=134, Predicted_Value=12426.090090, Expected_Value=12256.000000
# Every 5th Minute Entry=135, Predicted_Value=12205.072597, Expected_Value=12199.000000
# Every 5th Minute Entry=136, Predicted_Value=12142.858105, Expected_Value=12168.000000
# Every 5th Minute Entry=137, Predicted_Value=12106.604522, Expected_Value=11839.000000
# Every 5th Minute Entry=138, Predicted_Value=11772.477487, Expected_Value=11422.000000
# Every 5th Minute Entry=139, Predicted_Value=11350.639103, Expected_Value=10874.000000
# Every 5th Minute Entry=140, Predicted_Value=10798.238554, Expected_Value=9935.000000
# Every 5th Minute Entry=141, Predicted_Value=9855.409123, Expected_Value=9640.000000
# Every 5th Minute Entry=142, Predicted_Value=9557.265432, Expected_Value=9496.000000
# Every 5th Minute Entry=143, Predicted_Value=9410.899134, Expected_Value=9822.000000
# Every 5th Minute Entry=144, Predicted_Value=9735.376925, Expected_Value=9786.000000
# Every 5th Minute Entry=145, Predicted_Value=9698.739882, Expected_Value=9792.000000
# Every 5th Minute Entry=146, Predicted_Value=9705.000044, Expected_Value=9815.000000
# Every 5th Minute Entry=147, Predicted_Value=9729.139741, Expected_Value=9980.000000
# Every 5th Minute Entry=148, Predicted_Value=9896.112484, Expected_Value=10048.000000
# Every 5th Minute Entry=149, Predicted_Value=9966.845173, Expected_Value=10027.000000
# Every 5th Minute Entry=150, Predicted_Value=9949.242731, Expected_Value=9988.000000
# Every 5th Minute Entry=151, Predicted_Value=9914.189102, Expected_Value=9932.000000
# Every 5th Minute Entry=152, Predicted_Value=9862.552879, Expected_Value=9796.000000
# Every 5th Minute Entry=153, Predicted_Value=9731.191173, Expected_Value=9669.000000
# Every 5th Minute Entry=154, Predicted_Value=9608.954358, Expected_Value=9508.000000
# Every 5th Minute Entry=155, Predicted_Value=9452.690709, Expected_Value=9444.000000
# Every 5th Minute Entry=156, Predicted_Value=9393.255019, Expected_Value=9325.000000
# Every 5th Minute Entry=157, Predicted_Value=9278.500310, Expected_Value=8992.000000
# Every 5th Minute Entry=158, Predicted_Value=8949.300588, Expected_Value=8792.000000
# Every 5th Minute Entry=159, Predicted_Value=8752.551612, Expected_Value=8700.000000
# Every 5th Minute Entry=160, Predicted_Value=8663.165815, Expected_Value=8716.000000
# Every 5th Minute Entry=161, Predicted_Value=8681.074070, Expected_Value=8704.000000
# Every 5th Minute Entry=162, Predicted_Value=8670.228564, Expected_Value=8709.000000
# Every 5th Minute Entry=163, Predicted_Value=8675.605114, Expected_Value=8715.000000
# Every 5th Minute Entry=164, Predicted_Value=8681.202946, Expected_Value=8721.000000
# Every 5th Minute Entry=165, Predicted_Value=8686.044366, Expected_Value=8638.000000
# Every 5th Minute Entry=166, Predicted_Value=8601.173986, Expected_Value=8564.000000
# Every 5th Minute Entry=167, Predicted_Value=8524.656185, Expected_Value=8509.000000
# Every 5th Minute Entry=168, Predicted_Value=8466.573890, Expected_Value=8418.000000
# Every 5th Minute Entry=169, Predicted_Value=8372.025823, Expected_Value=8318.000000
# Every 5th Minute Entry=170, Predicted_Value=8268.123512, Expected_Value=8343.000000
# Every 5th Minute Entry=171, Predicted_Value=8288.986106, Expected_Value=8342.000000
# Every 5th Minute Entry=172, Predicted_Value=8283.735735, Expected_Value=8251.000000
# Every 5th Minute Entry=173, Predicted_Value=8188.504689, Expected_Value=8321.000000
# Every 5th Minute Entry=174, Predicted_Value=8254.427243, Expected_Value=8346.000000
# Every 5th Minute Entry=175, Predicted_Value=8275.629726, Expected_Value=8291.000000
# Every 5th Minute Entry=176, Predicted_Value=8217.228192, Expected_Value=8146.000000
# Every 5th Minute Entry=177, Predicted_Value=8069.325559, Expected_Value=8144.000000
# Every 5th Minute Entry=178, Predicted_Value=8065.008290, Expected_Value=8249.000000
# Every 5th Minute Entry=179, Predicted_Value=8168.344184, Expected_Value=8470.000000
# Every 5th Minute Entry=180, Predicted_Value=8388.380063, Expected_Value=9039.000000
# Every 5th Minute Entry=181, Predicted_Value=8957.140220, Expected_Value=9350.000000
# Every 5th Minute Entry=182, Predicted_Value=9268.625759, Expected_Value=9167.000000
# Every 5th Minute Entry=183, Predicted_Value=9086.812386, Expected_Value=8933.000000
# Every 5th Minute Entry=184, Predicted_Value=8854.652841, Expected_Value=8654.000000
# Every 5th Minute Entry=185, Predicted_Value=8578.081198, Expected_Value=8627.000000
# Every 5th Minute Entry=186, Predicted_Value=8554.013425, Expected_Value=8778.000000
# Every 5th Minute Entry=187, Predicted_Value=8708.350470, Expected_Value=8974.000000
# Every 5th Minute Entry=188, Predicted_Value=8907.981909, Expected_Value=9215.000000
# Every 5th Minute Entry=189, Predicted_Value=9152.789917, Expected_Value=9322.000000
# Every 5th Minute Entry=190, Predicted_Value=9263.652475, Expected_Value=9429.000000
# Every 5th Minute Entry=191, Predicted_Value=9374.448777, Expected_Value=9792.000000
# Every 5th Minute Entry=192, Predicted_Value=9741.063652, Expected_Value=10163.000000
# Every 5th Minute Entry=193, Predicted_Value=10115.381704, Expected_Value=10401.000000
# Every 5th Minute Entry=194, Predicted_Value=10356.305870, Expected_Value=10754.000000
# Every 5th Minute Entry=195, Predicted_Value=10711.757306, Expected_Value=11116.000000
# Every 5th Minute Entry=196, Predicted_Value=11075.670420, Expected_Value=11538.000000
# Every 5th Minute Entry=197, Predicted_Value=11498.995300, Expected_Value=12190.000000
# Every 5th Minute Entry=198, Predicted_Value=12151.699039, Expected_Value=12695.000000
# Every 5th Minute Entry=199, Predicted_Value=12656.768276, Expected_Value=13022.000000
# Every 5th Minute Entry=200, Predicted_Value=12983.208973, Expected_Value=13324.000000
# Every 5th Minute Entry=201, Predicted_Value=13284.045755, Expected_Value=13571.000000
# Every 5th Minute Entry=202, Predicted_Value=13529.321578, Expected_Value=13817.000000
# Every 5th Minute Entry=203, Predicted_Value=13773.094636, Expected_Value=14181.000000
# Every 5th Minute Entry=204, Predicted_Value=14134.437478, Expected_Value=14581.000000
# Every 5th Minute Entry=205, Predicted_Value=14531.435242, Expected_Value=14799.000000
# Every 5th Minute Entry=206, Predicted_Value=14746.182009, Expected_Value=14963.000000
# Every 5th Minute Entry=207, Predicted_Value=14906.773188, Expected_Value=15088.000000
# Every 5th Minute Entry=208, Predicted_Value=15028.315338, Expected_Value=15174.000000
# Every 5th Minute Entry=209, Predicted_Value=15110.918552, Expected_Value=15295.000000
# Every 5th Minute Entry=210, Predicted_Value=15228.688730, Expected_Value=15422.000000
# Every 5th Minute Entry=211, Predicted_Value=15352.724590, Expected_Value=15543.000000
# Every 5th Minute Entry=212, Predicted_Value=15471.115909, Expected_Value=15629.000000
# Every 5th Minute Entry=213, Predicted_Value=15554.940866, Expected_Value=15673.000000
# Every 5th Minute Entry=214, Predicted_Value=15597.263289, Expected_Value=15691.000000
# Every 5th Minute Entry=215, Predicted_Value=15614.131432, Expected_Value=15723.000000
# Every 5th Minute Entry=216, Predicted_Value=15645.575552, Expected_Value=15762.000000
# Every 5th Minute Entry=217, Predicted_Value=15684.607355, Expected_Value=15793.000000
# Every 5th Minute Entry=218, Predicted_Value=15716.219883, Expected_Value=15819.000000
# Every 5th Minute Entry=219, Predicted_Value=15743.386303, Expected_Value=15834.000000
# Every 5th Minute Entry=220, Predicted_Value=15760.062886, Expected_Value=15847.000000
# Every 5th Minute Entry=221, Predicted_Value=15775.190556, Expected_Value=15851.000000
# Every 5th Minute Entry=222, Predicted_Value=15781.697315, Expected_Value=15856.000000
# Every 5th Minute Entry=223, Predicted_Value=15789.499020, Expected_Value=15865.000000
# Every 5th Minute Entry=224, Predicted_Value=15801.504238, Expected_Value=15875.000000
# Every 5th Minute Entry=225, Predicted_Value=15814.617009, Expected_Value=15881.000000
# Every 5th Minute Entry=226, Predicted_Value=15823.738505, Expected_Value=15883.000000
# Every 5th Minute Entry=227, Predicted_Value=15828.771440, Expected_Value=15892.000000
# Every 5th Minute Entry=228, Predicted_Value=15840.624713, Expected_Value=15909.000000
# Every 5th Minute Entry=229, Predicted_Value=15860.207996, Expected_Value=15928.000000
# Every 5th Minute Entry=230, Predicted_Value=15881.445870, Expected_Value=15948.000000
# Every 5th Minute Entry=231, Predicted_Value=15903.278264, Expected_Value=15967.000000
# Every 5th Minute Entry=232, Predicted_Value=15923.656921, Expected_Value=15983.000000
# Every 5th Minute Entry=233, Predicted_Value=15940.545953, Expected_Value=15987.000000
# Every 5th Minute Entry=234, Predicted_Value=15944.923938, Expected_Value=15980.000000
# Every 5th Minute Entry=235, Predicted_Value=15937.786017, Expected_Value=15974.000000
# Every 5th Minute Entry=236, Predicted_Value=15931.143122, Expected_Value=15976.000000
# Every 5th Minute Entry=237, Predicted_Value=15932.020651, Expected_Value=15980.000000
# Every 5th Minute Entry=238, Predicted_Value=15934.458468, Expected_Value=15982.000000
# Every 5th Minute Entry=239, Predicted_Value=15934.508914, Expected_Value=15982.000000
# Every 5th Minute Entry=240, Predicted_Value=15932.235924, Expected_Value=15970.000000
# Every 5th Minute Entry=241, Predicted_Value=15917.712270, Expected_Value=15950.000000
# Every 5th Minute Entry=242, Predicted_Value=15895.011273, Expected_Value=15936.000000
# Every 5th Minute Entry=243, Predicted_Value=15878.217851, Expected_Value=15927.000000
# Every 5th Minute Entry=244, Predicted_Value=15866.421226, Expected_Value=15929.000000
# Every 5th Minute Entry=245, Predicted_Value=15865.708966, Expected_Value=15926.000000
# Every 5th Minute Entry=246, Predicted_Value=15860.164662, Expected_Value=15918.000000
# Every 5th Minute Entry=247, Predicted_Value=15849.864950, Expected_Value=15907.000000
# Every 5th Minute Entry=248, Predicted_Value=15836.879176, Expected_Value=15895.000000
# Every 5th Minute Entry=249, Predicted_Value=15823.266087, Expected_Value=15886.000000
# Every 5th Minute Entry=250, Predicted_Value=15813.073055, Expected_Value=15882.000000
# Every 5th Minute Entry=251, Predicted_Value=15808.332765, Expected_Value=15884.000000
# Every 5th Minute Entry=252, Predicted_Value=15810.064101, Expected_Value=15883.000000
# Every 5th Minute Entry=253, Predicted_Value=15809.270596, Expected_Value=15891.000000
# Every 5th Minute Entry=254, Predicted_Value=15817.940103, Expected_Value=15907.000000
# Every 5th Minute Entry=255, Predicted_Value=15835.045899, Expected_Value=15927.000000
# Every 5th Minute Entry=256, Predicted_Value=15856.548453, Expected_Value=15939.000000
# Every 5th Minute Entry=257, Predicted_Value=15870.395533, Expected_Value=15944.000000
# Every 5th Minute Entry=258, Predicted_Value=15877.524749, Expected_Value=15945.000000
# Every 5th Minute Entry=259, Predicted_Value=15880.865981, Expected_Value=15946.000000
# Every 5th Minute Entry=260, Predicted_Value=15884.343477, Expected_Value=15949.000000
# Every 5th Minute Entry=261, Predicted_Value=15889.878284, Expected_Value=15959.000000
# Every 5th Minute Entry=262, Predicted_Value=15902.391338, Expected_Value=15972.000000
# Every 5th Minute Entry=263, Predicted_Value=15917.804788, Expected_Value=15979.000000
# Every 5th Minute Entry=264, Predicted_Value=15927.045975, Expected_Value=15973.000000
# Every 5th Minute Entry=265, Predicted_Value=15923.045662, Expected_Value=15967.000000
# Every 5th Minute Entry=266, Predicted_Value=15918.745325, Expected_Value=15965.000000
# Every 5th Minute Entry=267, Predicted_Value=15918.099136, Expected_Value=15969.000000
# Every 5th Minute Entry=268, Predicted_Value=15923.071870, Expected_Value=15985.000000
# Every 5th Minute Entry=269, Predicted_Value=15939.638792, Expected_Value=15996.000000
# Every 5th Minute Entry=270, Predicted_Value=15950.787645, Expected_Value=15997.000000
# Every 5th Minute Entry=271, Predicted_Value=15951.518981, Expected_Value=15995.000000
# Every 5th Minute Entry=272, Predicted_Value=15948.846161, Expected_Value=15989.000000
# Every 5th Minute Entry=273, Predicted_Value=15941.794583, Expected_Value=15975.000000
# Every 5th Minute Entry=274, Predicted_Value=15926.400688, Expected_Value=15962.000000
# Every 5th Minute Entry=275, Predicted_Value=15911.711185, Expected_Value=15934.000000
# Every 5th Minute Entry=276, Predicted_Value=15881.780734, Expected_Value=15909.000000
# Every 5th Minute Entry=277, Predicted_Value=15854.666757, Expected_Value=15894.000000
# Every 5th Minute Entry=278, Predicted_Value=15837.435397, Expected_Value=15889.000000
# Every 5th Minute Entry=279, Predicted_Value=15830.158322, Expected_Value=15891.000000
# Every 5th Minute Entry=280, Predicted_Value=15829.907418, Expected_Value=15891.000000
# Every 5th Minute Entry=281, Predicted_Value=15827.752142, Expected_Value=15896.000000
# Every 5th Minute Entry=282, Predicted_Value=15830.757865, Expected_Value=15896.000000
# Every 5th Minute Entry=283, Predicted_Value=15828.984770, Expected_Value=15888.000000
# Every 5th Minute Entry=284, Predicted_Value=15819.485640, Expected_Value=15882.000000
# Every 5th Minute Entry=285, Predicted_Value=15812.304865, Expected_Value=15887.000000
# Every 5th Minute Entry=286, Predicted_Value=15816.476014, Expected_Value=15886.000000
# Every 5th Minute Entry=287, Predicted_Value=15815.021173, Expected_Value=15879.000000
# Every 5th Minute Entry=288, Predicted_Value=15807.950612, Expected_Value=15864.000000
# Every 5th Minute Entry=289, Predicted_Value=15793.262342, Expected_Value=15848.000000
# Every 5th Minute Entry=290, Predicted_Value=15777.942339, Expected_Value=15833.000000
# Every 5th Minute Entry=291, Predicted_Value=15763.964875, Expected_Value=15822.000000
# Every 5th Minute Entry=292, Predicted_Value=15754.293841, Expected_Value=15817.000000
# Every 5th Minute Entry=293, Predicted_Value=15750.883520, Expected_Value=15815.000000
# Every 5th Minute Entry=294, Predicted_Value=15750.681019, Expected_Value=15816.000000
# Every 5th Minute Entry=295, Predicted_Value=15753.628144, Expected_Value=15818.000000
# Every 5th Minute Entry=296, Predicted_Value=15757.662063, Expected_Value=15809.000000
# Every 5th Minute Entry=297, Predicted_Value=15750.718730, Expected_Value=15798.000000
# Every 5th Minute Entry=298, Predicted_Value=15741.733987, Expected_Value=15784.000000
# Every 5th Minute Entry=299, Predicted_Value=15729.646107, Expected_Value=15774.000000
# Every 5th Minute Entry=300, Predicted_Value=15721.397780, Expected_Value=15778.000000
# Every 5th Minute Entry=301, Predicted_Value=15726.936995, Expected_Value=15787.000000
# Every 5th Minute Entry=302, Predicted_Value=15737.217263, Expected_Value=15781.000000
# Every 5th Minute Entry=303, Predicted_Value=15732.203469, Expected_Value=15783.000000
# Every 5th Minute Entry=304, Predicted_Value=15734.870657, Expected_Value=15785.000000
# Every 5th Minute Entry=305, Predicted_Value=15737.203036, Expected_Value=15785.000000
# Every 5th Minute Entry=306, Predicted_Value=15737.194644, Expected_Value=15783.000000
# Every 5th Minute Entry=307, Predicted_Value=15734.850339, Expected_Value=15776.000000
# Every 5th Minute Entry=308, Predicted_Value=15727.184476, Expected_Value=15759.000000
# Every 5th Minute Entry=309, Predicted_Value=15709.220907, Expected_Value=15744.000000
# Every 5th Minute Entry=310, Predicted_Value=15692.992870, Expected_Value=15722.000000
# Every 5th Minute Entry=311, Predicted_Value=15669.540007, Expected_Value=15703.000000
# Every 5th Minute Entry=312, Predicted_Value=15648.907041, Expected_Value=15685.000000
# Every 5th Minute Entry=313, Predicted_Value=15629.145762, Expected_Value=15642.000000
# Every 5th Minute Entry=314, Predicted_Value=15584.312927, Expected_Value=15590.000000
# Every 5th Minute Entry=315, Predicted_Value=15530.466399, Expected_Value=15564.000000
# Every 5th Minute Entry=316, Predicted_Value=15502.663158, Expected_Value=15559.000000
# Every 5th Minute Entry=317, Predicted_Value=15495.958305, Expected_Value=15582.000000
# Every 5th Minute Entry=318, Predicted_Value=15517.403742, Expected_Value=15614.000000
# Every 5th Minute Entry=319, Predicted_Value=15548.045734, Expected_Value=15651.000000
# Every 5th Minute Entry=320, Predicted_Value=15583.925030, Expected_Value=15677.000000
# Every 5th Minute Entry=321, Predicted_Value=15609.073984, Expected_Value=15675.000000
# Every 5th Minute Entry=322, Predicted_Value=15606.516338, Expected_Value=15654.000000
# Every 5th Minute Entry=323, Predicted_Value=15585.266115, Expected_Value=15665.000000
# Every 5th Minute Entry=324, Predicted_Value=15596.327842, Expected_Value=15654.000000
# Every 5th Minute Entry=325, Predicted_Value=15585.695668, Expected_Value=15619.000000
# Every 5th Minute Entry=326, Predicted_Value=15551.355347, Expected_Value=15608.000000
# Every 5th Minute Entry=327, Predicted_Value=15541.282587, Expected_Value=15588.000000
# Every 5th Minute Entry=328, Predicted_Value=15522.444921, Expected_Value=15565.000000
# Every 5th Minute Entry=329, Predicted_Value=15500.803480, Expected_Value=15540.000000
# Every 5th Minute Entry=330, Predicted_Value=15477.313322, Expected_Value=15524.000000
# Every 5th Minute Entry=331, Predicted_Value=15462.925528, Expected_Value=15488.000000
# Every 5th Minute Entry=332, Predicted_Value=15428.588750, Expected_Value=15425.000000
# Every 5th Minute Entry=333, Predicted_Value=15367.250868, Expected_Value=15383.000000
# Every 5th Minute Entry=334, Predicted_Value=15326.860865, Expected_Value=15321.000000
# Every 5th Minute Entry=335, Predicted_Value=15266.369271, Expected_Value=15281.000000
# Every 5th Minute Entry=336, Predicted_Value=15227.731033, Expected_Value=15250.000000
# Every 5th Minute Entry=337, Predicted_Value=15197.906398, Expected_Value=15224.000000
# Every 5th Minute Entry=338, Predicted_Value=15172.861133, Expected_Value=15206.000000
# Every 5th Minute Entry=339, Predicted_Value=15155.567632, Expected_Value=15188.000000
# Every 5th Minute Entry=340, Predicted_Value=15138.008007, Expected_Value=15177.000000
# Every 5th Minute Entry=341, Predicted_Value=15127.173203, Expected_Value=15150.000000
# Every 5th Minute Entry=342, Predicted_Value=15100.062226, Expected_Value=15130.000000
# Every 5th Minute Entry=343, Predicted_Value=15079.681480, Expected_Value=15121.000000
# Every 5th Minute Entry=344, Predicted_Value=15070.045874, Expected_Value=15127.000000
# Every 5th Minute Entry=345, Predicted_Value=15075.178154, Expected_Value=15121.000000
# Every 5th Minute Entry=346, Predicted_Value=15068.105374, Expected_Value=15123.000000
# Every 5th Minute Entry=347, Predicted_Value=15068.862209, Expected_Value=15112.000000
# Every 5th Minute Entry=348, Predicted_Value=15056.489515, Expected_Value=15103.000000
# Every 5th Minute Entry=349, Predicted_Value=15046.031463, Expected_Value=15088.000000
# Every 5th Minute Entry=350, Predicted_Value=15029.533547, Expected_Value=15070.000000
# Every 5th Minute Entry=351, Predicted_Value=15010.042477, Expected_Value=15032.000000
# Every 5th Minute Entry=352, Predicted_Value=14970.604080, Expected_Value=15009.000000
# Every 5th Minute Entry=353, Predicted_Value=14946.262085, Expected_Value=14980.000000
# Every 5th Minute Entry=354, Predicted_Value=14916.057016, Expected_Value=14966.000000
# Every 5th Minute Entry=355, Predicted_Value=14901.025315, Expected_Value=14924.000000
# Every 5th Minute Entry=356, Predicted_Value=14858.197237, Expected_Value=14890.000000
# Every 5th Minute Entry=357, Predicted_Value=14823.595973, Expected_Value=14866.000000
# Every 5th Minute Entry=358, Predicted_Value=14799.237754, Expected_Value=14848.000000
# Every 5th Minute Entry=359, Predicted_Value=14781.131194, Expected_Value=14856.000000
# Every 5th Minute Entry=360, Predicted_Value=14789.276403, Expected_Value=14867.000000
# Every 5th Minute Entry=361, Predicted_Value=14800.666755, Expected_Value=14843.000000
# Every 5th Minute Entry=362, Predicted_Value=14777.286903, Expected_Value=14826.000000
# Every 5th Minute Entry=363, Predicted_Value=14761.114870, Expected_Value=14794.000000
# Every 5th Minute Entry=364, Predicted_Value=14730.122498, Expected_Value=14762.000000
# Every 5th Minute Entry=365, Predicted_Value=14699.276219, Expected_Value=14753.000000
# Every 5th Minute Entry=366, Predicted_Value=14691.538157, Expected_Value=14776.000000
# Every 5th Minute Entry=367, Predicted_Value=14715.867454, Expected_Value=14800.000000
# Every 5th Minute Entry=368, Predicted_Value=14741.222369, Expected_Value=14820.000000
# Every 5th Minute Entry=369, Predicted_Value=14762.560389, Expected_Value=14838.000000
# Every 5th Minute Entry=370, Predicted_Value=14781.840989, Expected_Value=14853.000000
# Every 5th Minute Entry=371, Predicted_Value=14798.025187, Expected_Value=14850.000000
# Every 5th Minute Entry=372, Predicted_Value=14796.077979, Expected_Value=14850.000000
# Every 5th Minute Entry=373, Predicted_Value=14796.968005, Expected_Value=14861.000000
# Every 5th Minute Entry=374, Predicted_Value=14808.669977, Expected_Value=14856.000000
# Every 5th Minute Entry=375, Predicted_Value=14804.165234, Expected_Value=14847.000000
# Every 5th Minute Entry=376, Predicted_Value=14795.440413, Expected_Value=14850.000000
# Every 5th Minute Entry=377, Predicted_Value=14798.490104, Expected_Value=14854.000000
# Every 5th Minute Entry=378, Predicted_Value=14802.315854, Expected_Value=14854.000000
# Every 5th Minute Entry=379, Predicted_Value=14801.925501, Expected_Value=14863.000000
# Every 5th Minute Entry=380, Predicted_Value=14810.333291, Expected_Value=14841.000000
# Every 5th Minute Entry=381, Predicted_Value=14787.559654, Expected_Value=14838.000000
# Every 5th Minute Entry=382, Predicted_Value=14783.630427, Expected_Value=14830.000000
# Every 5th Minute Entry=383, Predicted_Value=14774.575978, Expected_Value=14804.000000
# Every 5th Minute Entry=384, Predicted_Value=14747.429876, Expected_Value=14814.000000
# Every 5th Minute Entry=385, Predicted_Value=14756.228672, Expected_Value=14825.000000
# Every 5th Minute Entry=386, Predicted_Value=14766.009690, Expected_Value=14857.000000
# Every 5th Minute Entry=387, Predicted_Value=14796.810695, Expected_Value=14869.000000
# Every 5th Minute Entry=388, Predicted_Value=14807.668679, Expected_Value=14872.000000
# Every 5th Minute Entry=389, Predicted_Value=14809.617985, Expected_Value=14915.000000
# Every 5th Minute Entry=390, Predicted_Value=14851.690193, Expected_Value=14996.000000
# Every 5th Minute Entry=391, Predicted_Value=14931.913243, Expected_Value=15059.000000
# Every 5th Minute Entry=392, Predicted_Value=14994.309218, Expected_Value=15134.000000
# Every 5th Minute Entry=393, Predicted_Value=15068.895234, Expected_Value=15237.000000
# Every 5th Minute Entry=394, Predicted_Value=15171.681893, Expected_Value=15329.000000
# Every 5th Minute Entry=395, Predicted_Value=15263.673832, Expected_Value=15395.000000
# Every 5th Minute Entry=396, Predicted_Value=15329.868732, Expected_Value=15489.000000
# Every 5th Minute Entry=397, Predicted_Value=15424.258201, Expected_Value=15575.000000
# Every 5th Minute Entry=398, Predicted_Value=15510.828105, Expected_Value=15618.000000
# Every 5th Minute Entry=399, Predicted_Value=15554.558677, Expected_Value=15664.000000
# Every 5th Minute Entry=400, Predicted_Value=15601.424962, Expected_Value=15676.000000
# Every 5th Minute Entry=401, Predicted_Value=15614.398579, Expected_Value=15631.000000
# Every 5th Minute Entry=402, Predicted_Value=15570.447617, Expected_Value=15603.000000
# Every 5th Minute Entry=403, Predicted_Value=15543.538838, Expected_Value=15632.000000
# Every 5th Minute Entry=404, Predicted_Value=15573.638451, Expected_Value=15492.000000
# Every 5th Minute Entry=405, Predicted_Value=15434.711893, Expected_Value=15377.000000
# Every 5th Minute Entry=406, Predicted_Value=15320.726367, Expected_Value=15271.000000
# Every 5th Minute Entry=407, Predicted_Value=15215.651067, Expected_Value=15022.000000
# Every 5th Minute Entry=408, Predicted_Value=14967.458826, Expected_Value=14873.000000
# Every 5th Minute Entry=409, Predicted_Value=14819.126235, Expected_Value=14770.000000
# Every 5th Minute Entry=410, Predicted_Value=14716.634301, Expected_Value=14147.000000
# Every 5th Minute Entry=411, Predicted_Value=14093.969772, Expected_Value=13665.000000
# Every 5th Minute Entry=412, Predicted_Value=13612.124146, Expected_Value=13344.000000
# Every 5th Minute Entry=413, Predicted_Value=13291.094994, Expected_Value=12606.000000
# Every 5th Minute Entry=414, Predicted_Value=12552.885407, Expected_Value=11840.000000
# Every 5th Minute Entry=415, Predicted_Value=11786.503999, Expected_Value=11238.000000
# Every 5th Minute Entry=416, Predicted_Value=11183.964463, Expected_Value=11226.000000
# Every 5th Minute Entry=417, Predicted_Value=11171.284796, Expected_Value=10623.000000
# Every 5th Minute Entry=418, Predicted_Value=10567.487748, Expected_Value=10206.000000
# Every 5th Minute Entry=419, Predicted_Value=10149.599379, Expected_Value=9904.000000
# Every 5th Minute Entry=420, Predicted_Value=9846.647736, Expected_Value=9558.000000
# Every 5th Minute Entry=421, Predicted_Value=9499.662744, Expected_Value=9421.000000
# Every 5th Minute Entry=422, Predicted_Value=9361.674882, Expected_Value=8696.000000
# Every 5th Minute Entry=423, Predicted_Value=8635.715067, Expected_Value=8096.000000
# Every 5th Minute Entry=424, Predicted_Value=8034.812453, Expected_Value=7397.000000
# Every 5th Minute Entry=425, Predicted_Value=7334.994534, Expected_Value=7020.000000
# Every 5th Minute Entry=426, Predicted_Value=6957.285826, Expected_Value=6884.000000
# Every 5th Minute Entry=427, Predicted_Value=6820.706536, Expected_Value=6677.000000
# Every 5th Minute Entry=428, Predicted_Value=6613.273891, Expected_Value=6424.000000
# Every 5th Minute Entry=429, Predicted_Value=6359.999043, Expected_Value=5926.000000
# Every 5th Minute Entry=430, Predicted_Value=5861.889170, Expected_Value=5173.000000
# Every 5th Minute Entry=431, Predicted_Value=5108.945929, Expected_Value=4491.000000
# Every 5th Minute Entry=432, Predicted_Value=4427.165564, Expected_Value=4028.000000
# Every 5th Minute Entry=433, Predicted_Value=3964.539463, Expected_Value=3776.000000
# Every 5th Minute Entry=434, Predicted_Value=3713.053823, Expected_Value=3382.000000
# Every 5th Minute Entry=435, Predicted_Value=3319.691086, Expected_Value=3090.000000
# Every 5th Minute Entry=436, Predicted_Value=3028.430492, Expected_Value=2905.000000
# Every 5th Minute Entry=437, Predicted_Value=2844.247417, Expected_Value=2630.000000
# Every 5th Minute Entry=438, Predicted_Value=2570.115689, Expected_Value=2354.000000
# Every 5th Minute Entry=439, Predicted_Value=2295.007923, Expected_Value=2110.000000
# Every 5th Minute Entry=440, Predicted_Value=2051.895962, Expected_Value=1911.000000
# Every 5th Minute Entry=441, Predicted_Value=1853.752419, Expected_Value=1738.000000
# Every 5th Minute Entry=442, Predicted_Value=1681.551675, Expected_Value=1515.000000
# Every 5th Minute Entry=443, Predicted_Value=1459.269327, Expected_Value=1328.000000
# Every 5th Minute Entry=444, Predicted_Value=1272.884505, Expected_Value=1224.000000
# Every 5th Minute Entry=445, Predicted_Value=1169.379210, Expected_Value=911.000000
# Every 5th Minute Entry=446, Predicted_Value=856.739968, Expected_Value=605.000000
# Every 5th Minute Entry=447, Predicted_Value=550.957174, Expected_Value=401.000000
# Every 5th Minute Entry=448, Predicted_Value=347.026190, Expected_Value=282.000000
# Every 5th Minute Entry=449, Predicted_Value=227.946353, Expected_Value=217.000000
# Every 5th Minute Entry=450, Predicted_Value=162.721859, Expected_Value=246.000000
# Every 5th Minute Entry=451, Predicted_Value=191.361431, Expected_Value=226.000000
# Every 5th Minute Entry=452, Predicted_Value=170.877770, Expected_Value=259.000000
# Every 5th Minute Entry=453, Predicted_Value=203.286775, Expected_Value=269.000000
# Every 5th Minute Entry=454, Predicted_Value=212.608102, Expected_Value=251.000000
# Every 5th Minute Entry=455, Predicted_Value=193.863837, Expected_Value=209.000000
# Every 5th Minute Entry=456, Predicted_Value=151.077280, Expected_Value=231.000000
# Every 5th Minute Entry=457, Predicted_Value=172.273164, Expected_Value=233.000000
# Every 5th Minute Entry=458, Predicted_Value=173.476558, Expected_Value=144.000000
# Every 5th Minute Entry=459, Predicted_Value=83.712196, Expected_Value=85.000000
# Every 5th Minute Entry=460, Predicted_Value=24.003046, Expected_Value=81.000000
# Every 5th Minute Entry=461, Predicted_Value=19.370421, Expected_Value=77.000000
# Every 5th Minute Entry=462, Predicted_Value=14.833093, Expected_Value=76.000000
# Every 5th Minute Entry=463, Predicted_Value=13.406742, Expected_Value=61.000000
# Every 5th Minute Entry=464, Predicted_Value=-1.896817, Expected_Value=41.000000
# Every 5th Minute Entry=465, Predicted_Value=-22.069301, Expected_Value=23.000000
# Every 5th Minute Entry=466, Predicted_Value=-40.106624, Expected_Value=12.000000
# Every 5th Minute Entry=467, Predicted_Value=-51.009561, Expected_Value=3.000000
# Every 5th Minute Entry=468, Predicted_Value=-59.782527, Expected_Value=0.000000
# Every 5th Minute Entry=469, Predicted_Value=-62.434246, Expected_Value=0.000000
# Every 5th Minute Entry=470, Predicted_Value=-61.976755, Expected_Value=0.000000
# Every 5th Minute Entry=471, Predicted_Value=-61.425403, Expected_Value=1.000000
# Every 5th Minute Entry=472, Predicted_Value=-59.798851, Expected_Value=4.000000
# Every 5th Minute Entry=473, Predicted_Value=-56.117087, Expected_Value=46.000000
# Every 5th Minute Entry=474, Predicted_Value=-13.401864, Expected_Value=69.000000
# Every 5th Minute Entry=475, Predicted_Value=10.324402, Expected_Value=155.000000
# Every 5th Minute Entry=476, Predicted_Value=97.038741, Expected_Value=354.000000
# Every 5th Minute Entry=477, Predicted_Value=296.719181, Expected_Value=511.000000
# Every 5th Minute Entry=478, Predicted_Value=454.345291, Expected_Value=661.000000
# Every 5th Minute Entry=479, Predicted_Value=604.898631, Expected_Value=720.000000
# Every 5th Minute Entry=480, Predicted_Value=664.362858, Expected_Value=833.000000
# Every 5th Minute Entry=481, Predicted_Value=777.724610, Expected_Value=1085.000000
# Every 5th Minute Entry=482, Predicted_Value=1029.974281, Expected_Value=1249.000000
# Every 5th Minute Entry=483, Predicted_Value=1194.105135, Expected_Value=1252.000000
# Every 5th Minute Entry=484, Predicted_Value=1197.114963, Expected_Value=1363.000000
# Every 5th Minute Entry=485, Predicted_Value=1308.004538, Expected_Value=1473.000000
# Every 5th Minute Entry=486, Predicted_Value=1417.779050, Expected_Value=1549.000000
# Every 5th Minute Entry=487, Predicted_Value=1493.446781, Expected_Value=1721.000000
# Every 5th Minute Entry=488, Predicted_Value=1665.018883, Expected_Value=1938.000000
# Every 5th Minute Entry=489, Predicted_Value=1881.509824, Expected_Value=2094.000000
# Every 5th Minute Entry=490, Predicted_Value=2036.935945, Expected_Value=2260.000000
# Every 5th Minute Entry=491, Predicted_Value=2202.315798, Expected_Value=2378.000000
# Every 5th Minute Entry=492, Predicted_Value=2319.668707, Expected_Value=2453.000000
# Every 5th Minute Entry=493, Predicted_Value=2394.015101, Expected_Value=2447.000000
# Every 5th Minute Entry=494, Predicted_Value=2387.375850, Expected_Value=2640.000000
# Every 5th Minute Entry=495, Predicted_Value=2579.770169, Expected_Value=2790.000000
# Every 5th Minute Entry=496, Predicted_Value=2729.215946, Expected_Value=3063.000000
# Every 5th Minute Entry=497, Predicted_Value=3001.730186, Expected_Value=3358.000000
# Every 5th Minute Entry=498, Predicted_Value=3296.326803, Expected_Value=3589.000000
# Every 5th Minute Entry=499, Predicted_Value=3527.017723, Expected_Value=3873.000000
# Every 5th Minute Entry=500, Predicted_Value=3810.811229, Expected_Value=4289.000000
# Every 5th Minute Entry=501, Predicted_Value=4226.712840, Expected_Value=4579.000000
# Every 5th Minute Entry=502, Predicted_Value=4516.724324, Expected_Value=4827.000000
# Every 5th Minute Entry=503, Predicted_Value=4764.843914, Expected_Value=4684.000000
# Every 5th Minute Entry=504, Predicted_Value=4622.066863, Expected_Value=5491.000000
# Every 5th Minute Entry=505, Predicted_Value=5429.384887, Expected_Value=5654.000000
# Every 5th Minute Entry=506, Predicted_Value=5592.786944, Expected_Value=5625.000000
# Every 5th Minute Entry=507, Predicted_Value=5564.259674, Expected_Value=6113.000000
# Every 5th Minute Entry=508, Predicted_Value=6052.787616, Expected_Value=6191.000000
# Every 5th Minute Entry=509, Predicted_Value=6131.353765, Expected_Value=6020.000000
# Every 5th Minute Entry=510, Predicted_Value=5960.940123, Expected_Value=6147.000000
# Every 5th Minute Entry=511, Predicted_Value=6088.528246, Expected_Value=6452.000000
# Every 5th Minute Entry=512, Predicted_Value=6394.100027, Expected_Value=6994.000000
# Every 5th Minute Entry=513, Predicted_Value=6936.638018, Expected_Value=7181.000000
# Every 5th Minute Entry=514, Predicted_Value=7124.125876, Expected_Value=7136.000000
# Every 5th Minute Entry=515, Predicted_Value=7079.549246, Expected_Value=7965.000000
# Every 5th Minute Entry=516, Predicted_Value=7908.895870, Expected_Value=8491.000000
# Every 5th Minute Entry=517, Predicted_Value=8435.156142, Expected_Value=8143.000000
# Every 5th Minute Entry=518, Predicted_Value=8087.322663, Expected_Value=8598.000000
# Every 5th Minute Entry=519, Predicted_Value=8542.391899, Expected_Value=9571.000000
# Every 5th Minute Entry=520, Predicted_Value=9515.362637, Expected_Value=10975.000000
# Every 5th Minute Entry=521, Predicted_Value=10919.236642, Expected_Value=11682.000000
# Every 5th Minute Entry=522, Predicted_Value=11626.019546, Expected_Value=11563.000000
# Every 5th Minute Entry=523, Predicted_Value=11506.718859, Expected_Value=11204.000000
# Every 5th Minute Entry=524, Predicted_Value=11147.344407, Expected_Value=10695.000000
# Every 5th Minute Entry=525, Predicted_Value=10637.908891, Expected_Value=10244.000000
# Every 5th Minute Entry=526, Predicted_Value=10186.426444, Expected_Value=10171.000000
# Every 5th Minute Entry=527, Predicted_Value=10112.912526, Expected_Value=10881.000000
# Every 5th Minute Entry=528, Predicted_Value=10822.382927, Expected_Value=11153.000000
# Every 5th Minute Entry=529, Predicted_Value=11093.854433, Expected_Value=11153.000000
# Every 5th Minute Entry=530, Predicted_Value=11093.343606, Expected_Value=11557.000000
# Every 5th Minute Entry=531, Predicted_Value=11496.865797, Expected_Value=11980.000000
# Every 5th Minute Entry=532, Predicted_Value=11919.435250, Expected_Value=12341.000000
# Every 5th Minute Entry=533, Predicted_Value=12280.065105, Expected_Value=12592.000000
# Every 5th Minute Entry=534, Predicted_Value=12530.765853, Expected_Value=12308.000000
# Every 5th Minute Entry=535, Predicted_Value=12246.546107, Expected_Value=11776.000000
# Every 5th Minute Entry=536, Predicted_Value=11714.411610, Expected_Value=10979.000000
# Every 5th Minute Entry=537, Predicted_Value=10917.365783, Expected_Value=10256.000000
# Every 5th Minute Entry=538, Predicted_Value=10194.408739, Expected_Value=10074.000000
# Every 5th Minute Entry=539, Predicted_Value=10012.538378, Expected_Value=10279.000000
# Every 5th Minute Entry=540, Predicted_Value=10217.749510, Expected_Value=11298.000000
# Every 5th Minute Entry=541, Predicted_Value=11237.034959, Expected_Value=12729.000000
# Every 5th Minute Entry=542, Predicted_Value=12668.384675, Expected_Value=13190.000000
# Every 5th Minute Entry=543, Predicted_Value=13129.787285, Expected_Value=12635.000000
# Every 5th Minute Entry=544, Predicted_Value=12575.229427, Expected_Value=11464.000000
# Every 5th Minute Entry=545, Predicted_Value=11404.697187, Expected_Value=10465.000000
# Every 5th Minute Entry=546, Predicted_Value=10406.175880, Expected_Value=9642.000000
# Every 5th Minute Entry=547, Predicted_Value=9583.650156, Expected_Value=8954.000000
# Every 5th Minute Entry=548, Predicted_Value=8896.105659, Expected_Value=8462.000000
# Every 5th Minute Entry=549, Predicted_Value=8404.528587, Expected_Value=8178.000000
# Every 5th Minute Entry=550, Predicted_Value=8120.906461, Expected_Value=7861.000000
# Every 5th Minute Entry=551, Predicted_Value=7804.227798, Expected_Value=7724.000000
# Every 5th Minute Entry=552, Predicted_Value=7667.483543, Expected_Value=7892.000000
# Every 5th Minute Entry=553, Predicted_Value=7835.666738, Expected_Value=8219.000000
# Every 5th Minute Entry=554, Predicted_Value=8162.772304, Expected_Value=8318.000000
# Every 5th Minute Entry=555, Predicted_Value=8261.797923, Expected_Value=8254.000000
# Every 5th Minute Entry=556, Predicted_Value=8197.743925, Expected_Value=7753.000000
# Every 5th Minute Entry=557, Predicted_Value=7696.612851, Expected_Value=6851.000000
# Every 5th Minute Entry=558, Predicted_Value=6794.409558, Expected_Value=6287.000000
# Every 5th Minute Entry=559, Predicted_Value=6230.141225, Expected_Value=5983.000000
# Every 5th Minute Entry=560, Predicted_Value=5925.817128, Expected_Value=5564.000000
# Every 5th Minute Entry=561, Predicted_Value=5506.447425, Expected_Value=5515.000000
# Every 5th Minute Entry=562, Predicted_Value=5457.044152, Expected_Value=5608.000000
# Every 5th Minute Entry=563, Predicted_Value=5549.620230, Expected_Value=6099.000000
# Every 5th Minute Entry=564, Predicted_Value=6040.189131, Expected_Value=6438.000000
# Every 5th Minute Entry=565, Predicted_Value=6378.763663, Expected_Value=6661.000000
# Every 5th Minute Entry=566, Predicted_Value=6601.357520, Expected_Value=6921.000000
# Every 5th Minute Entry=567, Predicted_Value=6860.982737, Expected_Value=6991.000000
# ...
# Every 5th Minute Entry=1826, Predicted_Value=2003.223363, Expected_Value=1700.000000
# Every 5th Minute Entry=1827, Predicted_Value=1641.223584, Expected_Value=1550.000000
# Every 5th Minute Entry=1828, Predicted_Value=1491.223915, Expected_Value=1508.000000
# Every 5th Minute Entry=1829, Predicted_Value=1449.224246, Expected_Value=1215.000000
# Every 5th Minute Entry=1830, Predicted_Value=1156.224577, Expected_Value=1239.000000
# Every 5th Minute Entry=1831, Predicted_Value=1180.225019, Expected_Value=1216.000000
# Every 5th Minute Entry=1832, Predicted_Value=1157.225461, Expected_Value=1215.000000
# Every 5th Minute Entry=1833, Predicted_Value=1156.225682, Expected_Value=1069.000000
# Every 5th Minute Entry=1834, Predicted_Value=1010.225682, Expected_Value=842.000000
# Every 5th Minute Entry=1835, Predicted_Value=783.225792, Expected_Value=861.000000
# Every 5th Minute Entry=1836, Predicted_Value=802.226123, Expected_Value=833.000000
# Every 5th Minute Entry=1837, Predicted_Value=774.226344, Expected_Value=726.000000
# Every 5th Minute Entry=1838, Predicted_Value=667.226565, Expected_Value=565.000000
# Every 5th Minute Entry=1839, Predicted_Value=506.226565, Expected_Value=459.000000
# Every 5th Minute Entry=1840, Predicted_Value=400.226565, Expected_Value=439.000000
# Every 5th Minute Entry=1841, Predicted_Value=380.226455, Expected_Value=343.000000
# Every 5th Minute Entry=1842, Predicted_Value=284.226344, Expected_Value=296.000000
# Every 5th Minute Entry=1843, Predicted_Value=237.226344, Expected_Value=247.000000
# Every 5th Minute Entry=1844, Predicted_Value=188.226123, Expected_Value=249.000000
# Every 5th Minute Entry=1845, Predicted_Value=190.226013, Expected_Value=332.000000
# Every 5th Minute Entry=1846, Predicted_Value=273.226123, Expected_Value=479.000000
# Every 5th Minute Entry=1847, Predicted_Value=420.225903, Expected_Value=476.000000
# Every 5th Minute Entry=1848, Predicted_Value=417.225571, Expected_Value=374.000000
# Every 5th Minute Entry=1849, Predicted_Value=315.225019, Expected_Value=400.000000
# Every 5th Minute Entry=1850, Predicted_Value=341.224467, Expected_Value=505.000000
# Every 5th Minute Entry=1851, Predicted_Value=446.224025, Expected_Value=541.000000
# Every 5th Minute Entry=1852, Predicted_Value=482.223804, Expected_Value=485.000000
# Every 5th Minute Entry=1853, Predicted_Value=426.223804, Expected_Value=380.000000
# Every 5th Minute Entry=1854, Predicted_Value=321.223584, Expected_Value=309.000000
# Every 5th Minute Entry=1855, Predicted_Value=250.223363, Expected_Value=333.000000
# Every 5th Minute Entry=1856, Predicted_Value=274.223252, Expected_Value=355.000000
# Every 5th Minute Entry=1857, Predicted_Value=296.223252, Expected_Value=320.000000
# Every 5th Minute Entry=1858, Predicted_Value=261.223252, Expected_Value=204.000000
# Every 5th Minute Entry=1859, Predicted_Value=145.223252, Expected_Value=148.000000
# Every 5th Minute Entry=1860, Predicted_Value=89.223252, Expected_Value=88.000000
# Every 5th Minute Entry=1861, Predicted_Value=29.223363, Expected_Value=77.000000
# Every 5th Minute Entry=1862, Predicted_Value=18.223584, Expected_Value=67.000000
# Every 5th Minute Entry=1863, Predicted_Value=8.223915, Expected_Value=57.000000
# Every 5th Minute Entry=1864, Predicted_Value=-1.775864, Expected_Value=43.000000
# Every 5th Minute Entry=1865, Predicted_Value=-15.775533, Expected_Value=28.000000
# Every 5th Minute Entry=1866, Predicted_Value=-30.775091, Expected_Value=18.000000
# Every 5th Minute Entry=1867, Predicted_Value=-40.774870, Expected_Value=11.000000
# Every 5th Minute Entry=1868, Predicted_Value=-47.774760, Expected_Value=9.000000
# Every 5th Minute Entry=1869, Predicted_Value=-49.774650, Expected_Value=6.000000
# Every 5th Minute Entry=1870, Predicted_Value=-52.774539, Expected_Value=0.000000
# Every 5th Minute Entry=1871, Predicted_Value=-58.774208, Expected_Value=0.000000
# Every 5th Minute Entry=1872, Predicted_Value=-58.773987, Expected_Value=0.000000
# Every 5th Minute Entry=1873, Predicted_Value=-58.773766, Expected_Value=0.000000
# Every 5th Minute Entry=1874, Predicted_Value=-58.773656, Expected_Value=0.000000
# Every 5th Minute Entry=1875, Predicted_Value=-58.773545, Expected_Value=0.000000
# Every 5th Minute Entry=1876, Predicted_Value=-58.773435, Expected_Value=0.000000
# Every 5th Minute Entry=1877, Predicted_Value=-58.773656, Expected_Value=0.000000
# Every 5th Minute Entry=1878, Predicted_Value=-58.773987, Expected_Value=0.000000
# Every 5th Minute Entry=1879, Predicted_Value=-58.774097, Expected_Value=0.000000
# Every 5th Minute Entry=1880, Predicted_Value=-58.774097, Expected_Value=0.000000
# Every 5th Minute Entry=1881, Predicted_Value=-58.774208, Expected_Value=0.000000
# Every 5th Minute Entry=1882, Predicted_Value=-58.774539, Expected_Value=0.000000
# Every 5th Minute Entry=1883, Predicted_Value=-58.774539, Expected_Value=0.000000
# Every 5th Minute Entry=1884, Predicted_Value=-58.774650, Expected_Value=0.000000
# Every 5th Minute Entry=1885, Predicted_Value=-58.775091, Expected_Value=0.000000
# Every 5th Minute Entry=1886, Predicted_Value=-58.775533, Expected_Value=0.000000
# Every 5th Minute Entry=1887, Predicted_Value=-58.775864, Expected_Value=0.000000
# Every 5th Minute Entry=1888, Predicted_Value=-58.775975, Expected_Value=0.000000
# Every 5th Minute Entry=1889, Predicted_Value=-58.776196, Expected_Value=0.000000
# Every 5th Minute Entry=1890, Predicted_Value=-58.776416, Expected_Value=0.000000
# Every 5th Minute Entry=1891, Predicted_Value=-58.776527, Expected_Value=0.000000
# Every 5th Minute Entry=1892, Predicted_Value=-58.776527, Expected_Value=0.000000
# Every 5th Minute Entry=1893, Predicted_Value=-58.776527, Expected_Value=0.000000
# Every 5th Minute Entry=1894, Predicted_Value=-58.776527, Expected_Value=0.000000
# Every 5th Minute Entry=1895, Predicted_Value=-58.776527, Expected_Value=0.000000
# Every 5th Minute Entry=1896, Predicted_Value=-58.776416, Expected_Value=0.000000
# Every 5th Minute Entry=1897, Predicted_Value=-58.776085, Expected_Value=0.000000
# Every 5th Minute Entry=1898, Predicted_Value=-58.775975, Expected_Value=0.000000
# Every 5th Minute Entry=1899, Predicted_Value=-58.775864, Expected_Value=0.000000
# Every 5th Minute Entry=1900, Predicted_Value=-58.775423, Expected_Value=0.000000
# Every 5th Minute Entry=1901, Predicted_Value=-58.775202, Expected_Value=0.000000
# Every 5th Minute Entry=1902, Predicted_Value=-58.774981, Expected_Value=0.000000
# Every 5th Minute Entry=1903, Predicted_Value=-58.774870, Expected_Value=0.000000
# Every 5th Minute Entry=1904, Predicted_Value=-58.774760, Expected_Value=0.000000
# Every 5th Minute Entry=1905, Predicted_Value=-58.774760, Expected_Value=0.000000
# Every 5th Minute Entry=1906, Predicted_Value=-58.774539, Expected_Value=0.000000
# Every 5th Minute Entry=1907, Predicted_Value=-58.774208, Expected_Value=0.000000
# Every 5th Minute Entry=1908, Predicted_Value=-58.773987, Expected_Value=0.000000
# Every 5th Minute Entry=1909, Predicted_Value=-58.773877, Expected_Value=0.000000
# Every 5th Minute Entry=1910, Predicted_Value=-58.773766, Expected_Value=0.000000
# Every 5th Minute Entry=1911, Predicted_Value=-58.773545, Expected_Value=0.000000
# Every 5th Minute Entry=1912, Predicted_Value=-58.773766, Expected_Value=0.000000
# Every 5th Minute Entry=1913, Predicted_Value=-58.773987, Expected_Value=0.000000
# Every 5th Minute Entry=1914, Predicted_Value=-58.774097, Expected_Value=0.000000
# Every 5th Minute Entry=1915, Predicted_Value=-58.774097, Expected_Value=0.000000
# Every 5th Minute Entry=1916, Predicted_Value=-58.774097, Expected_Value=0.000000
# Every 5th Minute Entry=1917, Predicted_Value=-58.774429, Expected_Value=0.000000
# Every 5th Minute Entry=1918, Predicted_Value=-58.774650, Expected_Value=0.000000
# Every 5th Minute Entry=1919, Predicted_Value=-58.774760, Expected_Value=0.000000
# Every 5th Minute Entry=1920, Predicted_Value=-58.774870, Expected_Value=0.000000
# Every 5th Minute Entry=1921, Predicted_Value=-58.775202, Expected_Value=0.000000
# Every 5th Minute Entry=1922, Predicted_Value=-58.775643, Expected_Value=0.000000
# Every 5th Minute Entry=1923, Predicted_Value=-58.775975, Expected_Value=0.000000
# Every 5th Minute Entry=1924, Predicted_Value=-58.776196, Expected_Value=0.000000
# Every 5th Minute Entry=1925, Predicted_Value=-58.776306, Expected_Value=0.000000
# Every 5th Minute Entry=1926, Predicted_Value=-58.776306, Expected_Value=0.000000
# Every 5th Minute Entry=1927, Predicted_Value=-58.776306, Expected_Value=0.000000
# Every 5th Minute Entry=1928, Predicted_Value=-58.776416, Expected_Value=0.000000
# Every 5th Minute Entry=1929, Predicted_Value=-58.776527, Expected_Value=0.000000
# Every 5th Minute Entry=1930, Predicted_Value=-58.776416, Expected_Value=2.000000
# Every 5th Minute Entry=1931, Predicted_Value=-56.776196, Expected_Value=7.000000
# Every 5th Minute Entry=1932, Predicted_Value=-51.776085, Expected_Value=15.000000
# Every 5th Minute Entry=1933, Predicted_Value=-43.775864, Expected_Value=27.000000
# Every 5th Minute Entry=1934, Predicted_Value=-31.775643, Expected_Value=46.000000
# Every 5th Minute Entry=1935, Predicted_Value=-12.775423, Expected_Value=64.000000
# Every 5th Minute Entry=1936, Predicted_Value=5.224688, Expected_Value=82.000000
# Every 5th Minute Entry=1937, Predicted_Value=23.224798, Expected_Value=197.000000
# Every 5th Minute Entry=1938, Predicted_Value=138.225019, Expected_Value=331.000000
# Every 5th Minute Entry=1939, Predicted_Value=272.225130, Expected_Value=433.000000
# Every 5th Minute Entry=1940, Predicted_Value=374.225350, Expected_Value=515.000000
# Every 5th Minute Entry=1941, Predicted_Value=456.225461, Expected_Value=547.000000
# Every 5th Minute Entry=1942, Predicted_Value=488.225682, Expected_Value=498.000000
# Every 5th Minute Entry=1943, Predicted_Value=439.225792, Expected_Value=451.000000
# Every 5th Minute Entry=1944, Predicted_Value=392.225903, Expected_Value=535.000000
# Every 5th Minute Entry=1945, Predicted_Value=476.226123, Expected_Value=749.000000
# Every 5th Minute Entry=1946, Predicted_Value=690.226234, Expected_Value=1004.000000
# Every 5th Minute Entry=1947, Predicted_Value=945.226344, Expected_Value=1227.000000
# Every 5th Minute Entry=1948, Predicted_Value=1168.226234, Expected_Value=1435.000000
# Every 5th Minute Entry=1949, Predicted_Value=1376.226013, Expected_Value=1627.000000
# Every 5th Minute Entry=1950, Predicted_Value=1568.225903, Expected_Value=1804.000000
# Every 5th Minute Entry=1951, Predicted_Value=1745.225682, Expected_Value=1958.000000
# Every 5th Minute Entry=1952, Predicted_Value=1899.225571, Expected_Value=2146.000000
# Every 5th Minute Entry=1953, Predicted_Value=2087.225461, Expected_Value=2395.000000
# Every 5th Minute Entry=1954, Predicted_Value=2336.225350, Expected_Value=2687.000000
# Every 5th Minute Entry=1955, Predicted_Value=2628.225019, Expected_Value=3088.000000
# Every 5th Minute Entry=1956, Predicted_Value=3029.224577, Expected_Value=3532.000000
# Every 5th Minute Entry=1957, Predicted_Value=3473.224357, Expected_Value=3987.000000
# Every 5th Minute Entry=1958, Predicted_Value=3928.224246, Expected_Value=4558.000000
# Every 5th Minute Entry=1959, Predicted_Value=4499.224025, Expected_Value=5230.000000
# Every 5th Minute Entry=1960, Predicted_Value=5171.223915, Expected_Value=15706.000000
# Every 5th Minute Entry=1961, Predicted_Value=15647.223804, Expected_Value=15667.000000
# Every 5th Minute Entry=1962, Predicted_Value=15608.223694, Expected_Value=15614.000000
# Every 5th Minute Entry=1963, Predicted_Value=15555.223694, Expected_Value=15635.000000
# Every 5th Minute Entry=1964, Predicted_Value=15576.223694, Expected_Value=15720.000000
# Every 5th Minute Entry=1965, Predicted_Value=15661.223804, Expected_Value=15822.000000
# Every 5th Minute Entry=1966, Predicted_Value=15763.223804, Expected_Value=15959.000000
# Every 5th Minute Entry=1967, Predicted_Value=15900.223915, Expected_Value=15944.000000
# Every 5th Minute Entry=1968, Predicted_Value=15885.224136, Expected_Value=15878.000000
# Every 5th Minute Entry=1969, Predicted_Value=15819.224357, Expected_Value=15840.000000
# Every 5th Minute Entry=1970, Predicted_Value=15781.224688, Expected_Value=15866.000000
# Every 5th Minute Entry=1971, Predicted_Value=15807.224798, Expected_Value=15910.000000
# Every 5th Minute Entry=1972, Predicted_Value=15851.224798, Expected_Value=15926.000000
# Every 5th Minute Entry=1973, Predicted_Value=15867.224798, Expected_Value=15937.000000
# Every 5th Minute Entry=1974, Predicted_Value=15878.224909, Expected_Value=15943.000000
# Every 5th Minute Entry=1975, Predicted_Value=15884.225240, Expected_Value=15973.000000
# Every 5th Minute Entry=1976, Predicted_Value=15914.225461, Expected_Value=16000.000000
# Every 5th Minute Entry=1977, Predicted_Value=15941.225682, Expected_Value=16000.000000
# Every 5th Minute Entry=1978, Predicted_Value=15941.225792, Expected_Value=15990.000000
# Every 5th Minute Entry=1979, Predicted_Value=15931.225903, Expected_Value=15895.000000
# Every 5th Minute Entry=1980, Predicted_Value=15836.226013, Expected_Value=15766.000000
# Every 5th Minute Entry=1981, Predicted_Value=15707.226123, Expected_Value=15662.000000
# Every 5th Minute Entry=1982, Predicted_Value=15603.226013, Expected_Value=15538.000000
# Every 5th Minute Entry=1983, Predicted_Value=15479.226013, Expected_Value=15500.000000
# Every 5th Minute Entry=1984, Predicted_Value=15441.226013, Expected_Value=15359.000000
# Every 5th Minute Entry=1985, Predicted_Value=15300.225903, Expected_Value=15135.000000
# Every 5th Minute Entry=1986, Predicted_Value=15076.225792, Expected_Value=14927.000000
# Every 5th Minute Entry=1987, Predicted_Value=14868.225571, Expected_Value=14952.000000
# Every 5th Minute Entry=1988, Predicted_Value=14893.225350, Expected_Value=14794.000000
# Every 5th Minute Entry=1989, Predicted_Value=14735.225240, Expected_Value=14835.000000
# Every 5th Minute Entry=1990, Predicted_Value=14776.225130, Expected_Value=15268.000000
# Every 5th Minute Entry=1991, Predicted_Value=15209.224688, Expected_Value=15669.000000
# Every 5th Minute Entry=1992, Predicted_Value=15610.224246, Expected_Value=15807.000000
# Every 5th Minute Entry=1993, Predicted_Value=15748.224136, Expected_Value=15878.000000
# Every 5th Minute Entry=1994, Predicted_Value=15819.224136, Expected_Value=15940.000000
# Every 5th Minute Entry=1995, Predicted_Value=15881.224025, Expected_Value=16000.000000
# Every 5th Minute Entry=1996, Predicted_Value=15941.224025, Expected_Value=16000.000000
# Every 5th Minute Entry=1997, Predicted_Value=15941.224025, Expected_Value=16000.000000
# Every 5th Minute Entry=1998, Predicted_Value=15941.223915, Expected_Value=16000.000000
# Every 5th Minute Entry=1999, Predicted_Value=15941.223804, Expected_Value=15834.000000
# Every 5th Minute Entry=2000, Predicted_Value=15775.223804, Expected_Value=15724.000000
# Every 5th Minute Entry=2001, Predicted_Value=15665.223804, Expected_Value=15645.000000
# Every 5th Minute Entry=2002, Predicted_Value=15586.223915, Expected_Value=15404.000000
# Every 5th Minute Entry=2003, Predicted_Value=15345.224136, Expected_Value=15277.000000
# Every 5th Minute Entry=2004, Predicted_Value=15218.224357, Expected_Value=15535.000000
# Every 5th Minute Entry=2005, Predicted_Value=15476.224688, Expected_Value=15767.000000
# Every 5th Minute Entry=2006, Predicted_Value=15708.224798, Expected_Value=15848.000000
# Every 5th Minute Entry=2007, Predicted_Value=15789.224798, Expected_Value=15905.000000
# Every 5th Minute Entry=2008, Predicted_Value=15846.224909, Expected_Value=16000.000000
# Every 5th Minute Entry=2009, Predicted_Value=15941.225019, Expected_Value=16000.000000
# Every 5th Minute Entry=2010, Predicted_Value=15941.225130, Expected_Value=16000.000000
# Every 5th Minute Entry=2011, Predicted_Value=15941.225350, Expected_Value=16000.000000
# Every 5th Minute Entry=2012, Predicted_Value=15941.225461, Expected_Value=16000.000000
# Every 5th Minute Entry=2013, Predicted_Value=15941.225682, Expected_Value=16000.000000
# Every 5th Minute Entry=2014, Predicted_Value=15941.225903, Expected_Value=16000.000000
# Every 5th Minute Entry=2015, Predicted_Value=15941.225903, Expected_Value=16000.000000
# Every 5th Minute Entry=2016, Predicted_Value=15941.226013, Expected_Value=16000.000000

# %%
from sklearn.metrics import mean_squared_error
print("Root mean squared error: %.3f" % sqrt(mean_squared_error(Expected_Val, Y_pred)))
# Out:
# Root mean squared error: 58.774

# %%
# Plot between the predicted power by the system and the number of hours
from matplotlib import pyplot
pyplot.figure(figsize=(20,8))
pyplot.plot(Expectation_plot, label="True values")
pyplot.plot(Pred_plot, label="Predicted values")
pyplot.xlabel("Number of hours of future prediction/12 units=1 hour")
pyplot.ylabel("Power generated by system in (kW)")
pyplot.legend()
pyplot.show()

# %%
# Calculating Mean Absolute Percent Error - Performance Evaluation
from sklearn.metrics import mean_squared_error
mape = (np.mean(np.abs((Expectation - Prediction) / Expectation))*100)
print("Calculation of the Mean Absolute Percent Error: ", mape )
# Out:
# Calculation of the Mean Absolute Percent Error:  15.832540866991407
